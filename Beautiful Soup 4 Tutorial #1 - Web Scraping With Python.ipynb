# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmethan96/Data_science/blob/main/Beautiful%20Soup%204%20Tutorial%20%231%20-%20Web%20Scraping%20With%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Beautiful Soup 4 Tutorial #1 - Web Scraping With Python**

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.newegg.ca/msi-geforce-rtx-4070-ti-rtx-4070-ti-gaming-x-trio-12g/p/N82E16814137771?Item=N82E16814137771"
result = requests.get(url)

# %%
print(result.text)
# Out:
# <!DOCTYPE html><html lang="en-ca" class="show-tab-store"><head><title>MSI RTX 4070 Ti Graphics Card with 12GB DDR6 | Newegg.com - Newegg.ca</title><meta charSet="utf-8"/><meta http-equiv="content-type" content="text/html; charset=UTF-8"/><meta name="referrer" content="always"/><meta name="keywords" content="Newegg, Newegg.ca, MSI Gaming GeForce RTX 4070 Ti 12GB GDDR6X PCI Express 4.0 Video Card RTX 4070 Ti GAMING X TRIO 12G"/><meta name="description" content="Buy the MSI GeForce RTX 4070 Ti Graphics Card with 12GB DDR6, model GAMING X TRIO 12G. Get fast shipping &amp; top-rated customer service from Newegg!"/><meta property="og:image" content="https://c1.neweggimages.com/ProductImage/14-137-771-02.jpg"/><meta property="og:description" content="Buy MSI Gaming GeForce RTX 4070 Ti 12GB GDDR6X PCI Express 4.0 Video Card RTX 4070 Ti GAMING X TRIO 12G with fast shipping and top-rated customer service. Once you know, you Newegg!"/><meta property="og:title" content="MSI RTX 4070 Ti Graphics 
# ...

# %%
doc = BeautifulSoup(result.text, "html.parser")

# %%
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html class="show-tab-store" lang="en-ca">
#  <head>
#   <title>
#    MSI RTX 4070 Ti Graphics Card with 12GB DDR6 | Newegg.com - Newegg.ca
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="always" name="referrer"/>
#   <meta content="Newegg, Newegg.ca, MSI Gaming GeForce RTX 4070 Ti 12GB GDDR6X PCI Express 4.0 Video Card RTX 4070 Ti GAMING X TRIO 12G" name="keywords"/>
#   <meta content="Buy the MSI GeForce RTX 4070 Ti Graphics Card with 12GB DDR6, model GAMING X TRIO 12G. Get fast shipping &amp; top-rated customer service from Newegg!" name="description"/>
#   <meta content="https://c1.neweggimages.com/ProductImage/14-137-771-02.jpg" property="og:image"/>
#   <meta content="Buy MSI Gaming GeForce RTX 4070 Ti 12GB GDDR6X PCI Express 4.0 Video Card RTX 4070 Ti GAMING X TRIO 12G with fast shipping and top-rated customer service. Once you know, you Newegg!" property="og:description"/>
# ...

# %%
prices = doc.find_all(text = "$")
# Out:
# <ipython-input-6-bc46777ec5e4>:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   prices = doc.find_all(text = "$")

# %%
print(prices)
# Out:
# ['$', '$', '$', '$']

# %%
parent = prices[0].parent

# %%
print(parent)
# Out:
# <li class="price-current"><span class="price-current-label"></span>$<strong>1,199</strong><sup>.99</sup></li>

# %%
strong = parent.find("strong")

# %%
print(strong.string) ## geting the price of url = "https://www.newegg.ca/msi-geforce-rtx-4070-ti-rtx-4070-ti-gaming-x-trio-12g/p/N82E16814137771?Item=N82E16814137771"
# Out:
# 1,199
