# %%
# !pwd
# Out:
# /kaggle/working

# %%
import os 
import numpy as np

# %% [markdown]
# # 1. Importing Dataset and Labels

# %%
# Importing the labels in .npy format 
print("Importing .npy labels")
file_path_npy = '/kaggle/input/ahmethan/labels1.npy'
labels_npy = np.load(file_path_npy, allow_pickle=True)
print((f"the len of labels_npy {len(labels_npy)}"))
print(f"the type of the label_npy is {type(labels_npy)}\n")

# Importing the labels in .txt format
print("Importing .txt labels")
file_path_txt = os.listdir('/kaggle/input/labels1/labels')
print(f"the len of label_txt {len(file_path_txt)}") # it needs to be sorted
labels_txt = sorted(file_path_txt)
print(f"the type of the labels_txt is {type(labels_txt)}\n")

# Importing the images in .jpg (original format)
print("Importing .jpg imges")
images_path = os.listdir('/kaggle/input/dataset-vehicle1/images') # it needs to be sorted
print(f"the len of images list {len(images_path)}") 
images_list = sorted(images_path)
print(f"the type of the labels_txt is {type(images_list)}\n")
# Out:
# Importing .npy labels
# the len of labels_npy 8218
# the type of the label_npy is <class 'numpy.ndarray'>
#
# Importing .txt labels
# the len of label_txt 8219
# the type of the labels_txt is <class 'list'>
#
# Importing .jpg imges
# the len of images list 8219
# the type of the labels_txt is <class 'list'>

# %%
for i in range(len(labels_txt)):
    if labels_txt[i] == 'classes.txt':
               print(i)
# Out:
# 4411

# %%
print(labels_txt[4411])
# Out:
# classes.txt

# %%
labels_txt.remove(labels_txt[4411])

# %%
len(labels_txt)
# Out:
# 8218

# %%
print(len(images_list))
# Out:
# 8219

# %%
images_list[7000]
# Out:
# 'ulu2304_jpg.rf.a2ac2361e260a982bdd57d8097c12d6d.jpg'

# %%
labels_txt[7000]
# Out:
# 'ulu2305_jpg.rf.3e366e6134b99514819d39a063e5e773.txt'

# %%
# Checking the validity of images list and the corresponding labels list
print(labels_txt[500])
print(images_list[500])
# Out:
# Highway_117_2020-07-30_jpg.rf.46d77343ef898e15519abd22dc1c45ee.txt
# Highway_117_2020-07-30_jpg.rf.46d77343ef898e15519abd22dc1c45ee.jpg

# %%
# Removing .txt file from images list
for i in range(len(images_list)):
      if images_list[i].endswith(".txt"):
            print(f"the index of the .txt file is {i}")
# Out:
# the index of the .txt file is 5694

# %%
# Checking the 5694 index of images_list
images_list[5694]
# Out:
# 'train.txt'

# %%
# Removing the 5694 index of images_list
# Please DO NOT run this line of code more than 1 time!
images_list.remove(images_list[5694])

# %%
# Checking the 5694 index of images_list after removing the .txt file
images_list[5694]
# Out:
# 'ulu0_jpg.rf.fa56a0f31c0eb2390fe1096028be63e4.jpg'

# %%
import cv2

# Loading images and associate labels
labeled_images = {}

for i, image_path in enumerate(images_list):
    new_dir = '/kaggle/input/dataset-vehicle1/images'+'/'+image_path
    image = cv2.imread(new_dir)
    label = labels_npy[i] 
#     elif i >= 5694:
#         image = cv2.imread(image_path)
#         label = labels[i+1]  # Get the corresponding label from the loaded labels array

    labeled_images[image_path] = {'image': image, 'label': label}

# %% [markdown]
# # 2. Dataset Analyzing

# %%
# Checking the image
import matplotlib.pyplot as plt
image_test = labeled_images['Highway_0_2020-07-30_jpg.rf.09e9d4467f17b2b870a5d1b94a38774a.jpg']
image = image_test['image']
label = image_test['label']
print(f" the image size is {image.shape}")
print(label)
plt.imshow(image)
# Out:
#  the image size is (408, 408, 3)
# [[3.       0.509804 0.411765 0.107843 0.245098]
#  [2.       0.210784 0.616422 0.127451 0.232843]]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# %%
import torchvision.transforms as transforms
from torchvision.transforms import v2
import pathlib
import torch
import torchvision
import pathlib
from collections import defaultdict
import PIL.Image
import torch
import torch.utils.data
import torchvision
from torchvision import models, datasets
import torchvision.transforms.v2 as transforms

# %%
# Defining the bounding box
bbox_1 = label[0]
bbox_2 = label[1]
print(bbox_1,'\n')
print(bbox_2)
# Out:
# [3.       0.509804 0.411765 0.107843 0.245098]
#
# [2.       0.210784 0.616422 0.127451 0.232843]

# %%
def bbox_draw(bbox, shape):
    class_id, center_x_normalized, center_y_normalized, width_normalized, height_normalized = bbox
    
    center_x_pixel = int(center_x_normalized * shape[0])
    center_y_pixel = int(center_y_normalized * shape[1])
    width_pixel = int(width_normalized * shape[0])
    height_pixel = int(height_normalized * shape[1])

    # Convert center coordinates to top-left coordinates
    top_left_x = center_x_pixel - width_pixel // 2
    top_left_y = center_y_pixel - height_pixel // 2

    # Convert center coordinates to bottom-right coordinates
    bottom_right_x = center_x_pixel + width_pixel // 2
    bottom_right_y = center_y_pixel + height_pixel // 2

    bbox_pascal_voc = [top_left_x, top_left_y, bottom_right_x  ,bottom_right_y  , class_id]
    color = (255, 0, 0)  # Green color for bounding box
    img = cv2.rectangle(image, (top_left_x, top_left_y), (bottom_right_x, bottom_right_y), color, 2)

    return img, [bbox_pascal_voc]

# %%
first_bbox = bbox_draw(bbox_1, image.shape)
second_bbox = bbox_draw(bbox_2, image.shape)

# %%
first_bbox[1]
# Out:
# [[187, 119, 229, 217, 3.0]]

# %%
print(f"pixel values for first image and its class id {first_bbox[1]}")
# Out:
# pixel values for first image and its class id [[187, 119, 229, 217, 3.0]]

# %%
plt.imshow(first_bbox[0])

# %%
import albumentations as A

# Define the augmentation pipeline
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Rotate(limit=10, p=0.5),
    A.RandomRain(slant_lower=-10, slant_upper=10, drop_length=20, drop_width=1, drop_color=(200, 200, 200), blur_value=5, brightness_coefficient=0.7, p=0.5),
    A.RandomFog(fog_coef_lower=0.3, fog_coef_upper=0.7, alpha_coef=0.08, p=0.5),
    A.RandomSunFlare(flare_roi=(0, 0, 1, 0.5), angle_lower=0.5, angle_upper=1, p=0.5),
    A.RandomShadow(shadow_roi=(0, 0.5, 1, 1), num_shadows_lower=1, num_shadows_upper=2, shadow_dimension=5, p=0.5),
    A.RandomSnow(snow_point_lower=0.1, snow_point_upper=0.3, brightness_coeff=2.5, p=0.5),
    A.CLAHE(p=0.5),
    A.GridDistortion(p=0.5),
    A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),

], bbox_params=A.BboxParams(format='pascal_voc'))

# %%
len(first_bbox[1])
# Out:
# 1

# %%
augmented = transform(image= first_bbox[0], bboxes= first_bbox[1])
augmented_image = augmented['image']
augmented_bboxes = augmented['bboxes']

# %%
import cv2
import matplotlib.pyplot as plt

def display_image_with_bboxes(img, bboxes, labels=None):
    
    for idx, bbox in enumerate(bboxes):
        x_min, y_min, x_max, y_max = map(int, bbox[:-1])
        
        color = (0, 255, 0)  # Green color for bounding boxes
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color, 2)

    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
# Original image
plt.imshow(first_bbox[0])

# %%
# Augmented image
aug_image = display_image_with_bboxes(augmented_image, augmented_bboxes)

# %%
labels_npy[0][0][0]
# Out:
# 3.0

# %%
# Figuring out the number of each class in the given dataset
auto = 0
bus = 0
car = 0
lcv = 0
motorcycle = 0
multiaxle = 0
tractor = 0
truck = 0

for idx, label in enumerate(labels_npy):
    for j in range(len(labels_npy[idx])):
        if labels_npy[idx][j][0] == 0:
            auto += 1 
        if labels_npy[idx][j][0] == 1:
            bus += 1 
        if labels_npy[idx][j][0] == 2:
            car += 1
        if labels_npy[idx][j][0] == 3:
             lcv+= 1
        if labels_npy[idx][j][0] == 4:
            motorcycle += 1
        if labels_npy[idx][j][0] == 5:
            multiaxle += 1
        if labels_npy[idx][j][0] == 6:
            tractor += 1 
        if labels_npy[idx][j][0] == 7:
            truck += 1

# %%
print(auto)
print(bus)
print(car)
print(lcv)
print(motorcycle)
print(multiaxle)
print(tractor)
print(truck)
# Out:
# 819
# 1319
# 11425
# 969
# 7285
# 1147
# 171
# 2963

# %%
total = (auto)+(bus)+(car)+(lcv)+(motorcycle)+(multiaxle)+(tractor)+(truck)

print(f"the total amount of vehicle classes {total}")
# Out:
# the total amount of vehicle classes 26098

# %%
vehicle_classes = ['auto', 'bus', 'car', 'lcv', 'motorcycle', 'multiaxle', 'tractor', 'truck']
vehicles_qunatity = [819, 1319, 11425, 969, 7285, 1147, 171, 2963]
colors = ['#ff9999','#66b2ff','#99ff99','#ffcc99', '#c2c2f0','#ffb3e6', '#ff6644']

# %%
plt.figure(figsize=(10,7))
plt.pie(vehicles_qunatity, labels= vehicle_classes, colors= colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of 7 Classes\n')
plt.show()

# %% [markdown]
# # 3. Training The Model

# %%
import cv2
import numpy as np
import torch
from torchvision import transforms
from torch.utils.data import Dataset
import albumentations as A
from torch.utils.data import Dataset

# %%
from albumentations import (
    HorizontalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine,
    IAASharpen, IAAEmboss, RandomBrightnessContrast, Flip, OneOf, Compose
)
from albumentations.pytorch import ToTensorV2

# Define your transformations as before, but now include bbox_params
albu_transform = A.Compose([
    A.HorizontalFlip(),
    A.ShiftScaleRotate(rotate_limit=15,value=0,
    border_mode=cv2.BORDER_CONSTANT),
                           A.CLAHE(),
                           A.GaussNoise(),
    A.LongestMaxSize(max_size=416),
    A.PadIfNeeded(min_height=416, min_width=416, border_mode=0),
    ],
    A.BboxParams(format='pascal_voc', label_fields=['labels']))
#     bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})
    # Your transformations here...
#     A.HorizontalFlip(p=0.5),
#     A.RandomBrightnessContrast(p=0.5),
#     A.Rotate(limit=10, p=0.5),
#     A.RandomRain(slant_lower=-10, slant_upper=10, drop_length=20, drop_width=1, drop_color=(200, 200, 200), blur_value=5, brightness_coefficient=0.7, p=0.5),
#     A.RandomFog(fog_coef_lower=0.3, fog_coef_upper=0.7, alpha_coef=0.08, p=0.5),
#     A.RandomSunFlare(flare_roi=(0, 0, 1, 0.5), angle_lower=0.5, angle_upper=1, p=0.5),
#     A.RandomShadow(shadow_roi=(0, 0.5, 1, 1), num_shadows_lower=1, num_shadows_upper=2, shadow_dimension=5, p=0.5),
#     A.RandomSnow(snow_point_lower=0.1, snow_point_upper=0.3, brightness_coeff=2.5, p=0.5),
#     A.CLAHE(p=0.5),
#     A.GridDistortion(p=0.5),
#     A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),
#     ToTensorV2(p=1.0)
# ],

# %%
# # Defining Albumentations's transform
# albu_transform = A.Compose([
#     A.HorizontalFlip(p=0.5),
#     A.RandomBrightnessContrast(p=0.5),
#     A.Rotate(limit=10, p=0.5),
#     A.RandomRain(slant_lower=-10, slant_upper=10, drop_length=20, drop_width=1, drop_color=(200, 200, 200), blur_value=5, brightness_coefficient=0.7, p=0.5),
#     A.RandomFog(fog_coef_lower=0.3, fog_coef_upper=0.7, alpha_coef=0.08, p=0.5),
#     A.RandomSunFlare(flare_roi=(0, 0, 1, 0.5), angle_lower=0.5, angle_upper=1, p=0.5),
#     A.RandomShadow(shadow_roi=(0, 0.5, 1, 1), num_shadows_lower=1, num_shadows_upper=2, shadow_dimension=5, p=0.5),
#     A.RandomSnow(snow_point_lower=0.1, snow_point_upper=0.3, brightness_coeff=2.5, p=0.5),
#     A.CLAHE(p=0.5),
#     A.GridDistortion(p=0.5),
#     A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),

# ], bbox_params=A.BboxParams(format='pascal_voc'))

# %%
# Defining PyTorch's transform
torch_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
print(f"len of images {len(images_list)} and len of labels {len(labels_npy)}")
# Out:
# len of images 8218 and len of labels 8218

# %%
dataset = list(zip(images_list, labels_npy))

# %%
class_to_idx = {cls: idx for idx, cls in enumerate(vehicle_classes)}
idx_to_class = {idx: cls for cls, idx in class_to_idx.items()}

# %%
print((class_to_idx))
# Out:
# {'auto': 0, 'bus': 1, 'car': 2, 'lcv': 3, 'motorcycle': 4, 'multiaxle': 5, 'tractor': 6, 'truck': 7}

# %%
print(idx_to_class)
# Out:
# {0: 'auto', 1: 'bus', 2: 'car', 3: 'lcv', 4: 'motorcycle', 5: 'multiaxle', 6: 'tractor', 7: 'truck'}

# %%
images_path = '/kaggle/input/dataset-vehicle1/images'

# %%
labels_path = '/kaggle/input/labels1/labels'

# %%
labels_path
# Out:
# '/kaggle/input/labels1/labels'

# %%
from PIL import Image
import torch

# %%
import os
import pandas as pd
from PIL import Image
import torch
from torch.utils.data import Dataset
import torchvision.transforms as transforms
import albumentations as A
from albumentations.pytorch import ToTensorV2

class CustomDataset(Dataset):
    def __init__(self, image_paths, label_paths, classes, transform=None):
        self.image_paths = image_paths
        self.label_paths = label_paths
        self.transform = transform
        self.classes = classes
        self.class_to_idx = {class_name: idx for idx, class_name in enumerate(self.classes)}
        self.idx_to_class = {idx: class_name for class_name, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load image and annotations
        img_path = self.image_paths[idx]
        annot_path = self.label_paths[idx]
        
        img = Image.open('/kaggle/input/dataset-vehicle1/images/'+img_path).convert("RGB")
        w, h = img.size
        
        if os.path.getsize('/kaggle/input/labels1/labels/'+annot_path) == 0:
            print(f"Annotation file {annot_path} is empty!")
            # Decide how you want to handle this situation. 
            # For example, return default values or skip the processing of this image.
            # Here's a placeholder return that you can replace:
            return img, {"boxes": torch.tensor([]), "labels": torch.tensor([]), "image_id": torch.tensor(idx)}

        
        annot_data = pd.read_csv('/kaggle/input/labels1/labels/'+annot_path, delimiter=" ", header=None).values
        class_data = annot_data[:, 0]
        class_idx = class_data
        
#         class_idx = class_data.flatten()

         
        boxes = []
        labels = []
        for bbox in annot_data:
            class_name_or_idx, center_x_normalized, center_y_normalized, width_normalized, height_normalized = bbox
            center_x_pixel = int(center_x_normalized * w)
            center_y_pixel = int(center_y_normalized * h)
            width_pixel = int(width_normalized * w)
            height_pixel = int(height_normalized * h)
            
            # Convert (center_x, center_y, width, height) to (x_min, y_min, x_max, y_max)
            top_left_x = center_x_pixel - width_pixel // 2
            top_left_y = center_y_pixel - height_pixel // 2
            bottom_right_x = center_x_pixel + width_pixel // 2
            bottom_right_y = center_y_pixel + height_pixel // 2

            boxes.append([top_left_x, top_left_y, bottom_right_x, bottom_right_y])
            labels.append(int(class_idx[0].flatten()))
            

        # Apply transformations
        if self.transform is not None:
            try:
                print(f"Index: {idx}, Boxes: {boxes}")
                augmented = self.transform(image=np.array(img), bboxes=boxes, labels=labels)
                img = augmented['image']
                boxes = augmented['bboxes']
                labels = augmented['labels'] ## added this
                
            except Exception as e:
                print(f"Error at index {idx}: {e}")
           
            
#             boxes = torch.tensor(augmented['bboxes'])
#         img = torch.from_numpy(img).permute(2, 0, 1).float() / 255.0
        img = np.array(img)  # Convert the PIL Image to a numpy ndarray
        img = torch.from_numpy(img).permute(2, 0, 1).float() / 255.5
        target = {
            "boxes": torch.tensor(boxes, dtype=torch.float32),
            "labels": torch.tensor(labels, dtype=torch.int64),
            "image_id": torch.tensor(idx)
        }
        print(f"Index: {idx}")
        print("Image Shape:", np.array(img).shape)
        print("Boxes:", boxes)
        print("Labels:", labels)

        return img, target

# %%
from sklearn.model_selection import train_test_split

train_image_paths, test_image_paths, train_label_paths, test_label_paths = train_test_split(
    images_list, labels_txt, test_size=0.2, random_state=42
)

# %%
print(len(images_list))
# Out:
# 8218

# %%
print(len(labels_txt))
# Out:
# 8218

# %%
print(f" the len of test set {len(train_image_paths)}, the len of train set {len(test_image_paths)}")
# Out:
#  the len of test set 6574, the len of train set 1644

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data
datasets = ['Training', 'Testing']
sizes = [6574, 1644]
colors = ['skyblue', 'yellowgreen']
explode = (0.1, 0)  

# Plotting
plt.figure(figsize=(10, 7))
sns.set_theme(style="whitegrid")
sns.set_palette("pastel")

plt.pie(sizes, explode=explode, labels=datasets, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal') 
plt.title("Distribution of Images in Training and Testing Sets", fontsize=15)
plt.show()

# %%
train_dataset = CustomDataset(train_image_paths, train_label_paths, classes=vehicle_classes, transform=albu_transform)
test_dataset = CustomDataset(test_image_paths, test_label_paths, classes=vehicle_classes, transform=albu_transform)
# train_dataset = CustomDataset(train_image_paths, train_label_paths, classes=vehicle_classes)
# test_dataset = CustomDataset(test_image_paths, test_label_paths, classes=vehicle_classes)

# %%
# print(train_dataset[5694])
print(train_dataset[6379])
# Out:
# Index: 6379, Boxes: [[8, 174, 112, 344]]
# Index: 6379
# Image Shape: (3, 416, 416)
# Boxes: [(8.533333333333333, 185.60000000000002, 119.46666666666665, 366.93333333333334)]
# Labels: [1]
# (tensor([[[0.0626, 0.0039, 0.0000,  ..., 0.0039, 0.0196, 0.0157],
#          [0.0078, 0.0196, 0.0039,  ..., 0.0000, 0.0078, 0.0157],
#          [0.0274, 0.0313, 0.0039,  ..., 0.0509, 0.0626, 0.0157],
#          ...,
#          [0.4188, 0.3914, 0.4070,  ..., 0.3679, 0.5010, 0.6067],
#          [0.3405, 0.3562, 0.3640,  ..., 0.4227, 0.5166, 0.6027],
#          [0.3249, 0.3718, 0.3366,  ..., 0.4423, 0.5362, 0.5871]],
#
#         [[0.0000, 0.0274, 0.0039,  ..., 0.0157, 0.0157, 0.0235],
#          [0.0078, 0.0431, 0.0509,  ..., 0.0117, 0.0352, 0.0039],
#          [0.0274, 0.0078, 0.0235,  ..., 0.0157, 0.0196, 0.1135],
#          ...,
#          [0.5323, 0.5245, 0.5440,  ..., 0.4618, 0.5793, 0.6614],
#          [0.5010, 0.5088, 0.5323,  ..., 0.4853, 0.5636, 0.6575],
#          [0.4971, 0.5049, 0.5166,  ..., 0.4775, 0.5832, 0.6458]],
#
#         [[0.0196, 0.0117, 0.0078,  ..., 0.0274, 0.0000, 0.0117],
#          [0.0235, 0.0235, 0.0039,  ..., 0.0274, 0.0352, 0.0000],
#          [0.0117, 0.0626, 0.0391,  ..., 0.0157, 0.0352, 0.0000],
#          ...,
#          [0.5988, 0.6184, 0.6184,  ..., 0.2818, 0.4227, 0.4814],
#          [0.5284, 0.5636, 0.6027,  ..., 0.3679, 0.4462, 0.5479],
#          [0.5401, 0.5675, 0.5832,  ..., 0.3562, 0.4384, 0.5284]]]), {'boxes': tensor([[  8.5333, 185.6000, 119.4667, 366.9333]]), 'labels': tensor([1]), 'image_id': tensor(6379)})

# %%
def collate_fn(batch):
    return tuple(zip(*batch))

# %%
from torch.utils.data import DataLoader
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# training_loader= DataLoader(train_dataset, batch_size=4,shuffle=True,num_workers=os.cpu_count(),
#                     collate_fn=collate_fn,
#                     pin_memory=True if device=="cuda" else False)
# testing_loader = DataLoader(test_dataset, batch_size=4,shuffle=False,num_workers=os.cpu_count(),
#                   collate_fn=collate_fn,
#                   pin_memory=True if device=="cuda" else False)
# training_loader= DataLoader(train_dataset, batch_size=2,shuffle=True,num_workers= 0,
#                     collate_fn=collate_fn,
#                     pin_memory=True if device=="cuda" else False)
# testing_loader = DataLoader(test_dataset, batch_size=4,shuffle=False,num_workers=0,
#                   collate_fn=collate_fn,
#                   pin_memory=True if device=="cuda" else False)

# %%
vehicle_classes = ['auto', 'bus', 'car', 'lcv', 'motorcycle', 'multiaxle', 'tractor', 'truck']
class_to_idx = {cls: idx for idx, cls in enumerate(vehicle_classes)}

# %%
train_dataset[0]
# Out:
# Index: 0, Boxes: [[56, 206, 110, 332], [138, 70, 154, 94]]
# Index: 0
# Image Shape: (3, 416, 416)
# Boxes: [(56.0, 206.0, 110.0, 332.0), (138.0, 70.0, 154.0, 94.0)]
# Labels: [2, 2]
# (tensor([[[0.0039, 0.0039, 0.0039,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0039, 0.0039, 0.0039,  ..., 0.0000, 0.0039, 0.0039],
#           [0.0000, 0.0078, 0.0157,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0313, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0039, 0.0078, 0.0078],
#           [0.0000, 0.0078, 0.0157,  ..., 0.0039, 0.0039, 0.0039],
#           ...,
#           [0.0000, 0.0000, 0.0039,  ..., 0.0235, 0.0117, 0.0078],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0235, 0.0313, 0.0078],
#           [0.0039, 0.0039, 0.0000,  ..., 0.0235, 0.0587, 0.0078]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0078, 0.0078, 0.0078],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0117, 0.0157, 0.0157],
#           [0.0000, 0.0078, 0.0157,  ..., 0.0157, 0.0157, 0.0157],
#           ...,
#           [0.0078, 0.0078, 0.0117,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0078, 0.0078, 0.0078,  ..., 0.0000, 0.0039, 0.0000],
#           [0.0117, 0.0117, 0.0078,  ..., 0.0000, 0.0313, 0.0000]]]),
#  {'boxes': tensor([[ 56., 206., 110., 332.],
#           [138.,  70., 154.,  94.]]),
#   'labels': tensor([2, 2]),
#   'image_id': tensor(0)})

# %%
train_dataset[1]
# Out:
# Index: 1, Boxes: [[62, 223, 104, 299], [199, 78, 219, 104]]
# Index: 1
# Image Shape: (3, 416, 416)
# Boxes: [(90.37469286185473, 265.07846601072197, 145.5194980363601, 347.2971699271631), (197.99535338826527, 101.80141941171647, 222.38072326724702, 130.96453612751046)]
# Labels: [2, 2]
# (tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0117],
#           [0.0117, 0.0000, 0.0196,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0157, 0.0000,  ..., 0.0039, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0235,  ..., 0.0157, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0039, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0078,  ..., 0.0117, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0157],
#           [0.0000, 0.0000, 0.0117,  ..., 0.0000, 0.0000, 0.0196],
#           [0.0117, 0.0157, 0.0000,  ..., 0.0078, 0.0000, 0.0274],
#           ...,
#           [0.0000, 0.0039, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0039, 0.0000,  ..., 0.0235, 0.0000, 0.0117],
#           [0.0000, 0.0117, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0196, 0.0157, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0078, 0.0000,  ..., 0.0078, 0.0000, 0.0000],
#           [0.0000, 0.0039, 0.0039,  ..., 0.0196, 0.0000, 0.0078],
#           ...,
#           [0.0157, 0.0000, 0.0078,  ..., 0.0352, 0.0000, 0.0000],
#           [0.0196, 0.0000, 0.0352,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0157, 0.0000, 0.0000,  ..., 0.0274, 0.0078, 0.0000]]]),
#  {'boxes': tensor([[ 90.3747, 265.0785, 145.5195, 347.2972],
#           [197.9953, 101.8014, 222.3807, 130.9645]]),
#   'labels': tensor([2, 2]),
#   'image_id': tensor(1)})

# %%
train_dataset[0][0]
# Out:
# Index: 0, Boxes: [[56, 206, 110, 332], [138, 70, 154, 94]]
# Index: 0
# Image Shape: (3, 416, 416)
# Boxes: [(305.6255059211534, 214.6970397646962, 386.187735368176, 359.0655584873371), (301.88420371449735, 61.46653642044162, 323.3317152180367, 90.00363562127194)]
# Labels: [2, 2]
# tensor([[[0.0157, 0.0157, 0.0157,  ..., 0.0117, 0.0117, 0.0117],
#          [0.0157, 0.0157, 0.0157,  ..., 0.0117, 0.0117, 0.0117],
#          [0.0157, 0.0157, 0.0157,  ..., 0.0157, 0.0117, 0.0117],
#          ...,
#          [0.0157, 0.0157, 0.0157,  ..., 0.3836, 0.3718, 0.0900],
#          [0.0157, 0.0157, 0.0157,  ..., 0.2779, 0.2896, 0.0509],
#          [0.0157, 0.0157, 0.0157,  ..., 0.2309, 0.2387, 0.0078]],
#
#         [[0.0157, 0.0157, 0.0157,  ..., 0.0117, 0.0117, 0.0117],
#          [0.0157, 0.0157, 0.0157,  ..., 0.0117, 0.0117, 0.0117],
#          [0.0157, 0.0157, 0.0157,  ..., 0.0157, 0.0117, 0.0117],
#          ...,
#          [0.0157, 0.0157, 0.0157,  ..., 0.4971, 0.4853, 0.1487],
#          [0.0157, 0.0157, 0.0157,  ..., 0.4031, 0.4031, 0.0978],
#          [0.0157, 0.0157, 0.0157,  ..., 0.3679, 0.3679, 0.0705]],
#
#         [[0.0157, 0.0157, 0.0157,  ..., 0.0117, 0.0117, 0.0117],
#          [0.0157, 0.0157, 0.0157,  ..., 0.0117, 0.0117, 0.0117],
#          [0.0157, 0.0157, 0.0157,  ..., 0.0157, 0.0117, 0.0117],
#          ...,
#          [0.0157, 0.0157, 0.0157,  ..., 0.5675, 0.5558, 0.1840],
#          [0.0157, 0.0157, 0.0157,  ..., 0.4697, 0.4697, 0.1213],
#          [0.0157, 0.0157, 0.0157,  ..., 0.4305, 0.4305, 0.0783]]])

# %%
train_dataset[0][1]
# Out:
# Index: 0, Boxes: [[56, 206, 110, 332], [138, 70, 154, 94]]
# Index: 0
# Image Shape: (3, 416, 416)
# Boxes: [(56.0, 206.0, 110.0, 332.0), (138.0, 70.0, 154.0, 94.0)]
# Labels: [2, 2]
# {'boxes': tensor([[ 56., 206., 110., 332.],
#          [138.,  70., 154.,  94.]]),
#  'labels': tensor([2, 2]),
#  'image_id': tensor(0)}

# %%
image_test = labeled_images['Highway_823_2020-07-30_jpg.rf.daf1e02d85aac9e064d236b4900b109e.jpg']
image = image_test['image']
label = image_test['label']
print(f" the image size is {image.shape}")
print(label)
# plt.imshow(image)
# Out:
#  the image size is (416, 416, 3)
# [[2.       0.23125  0.401563 0.079167 0.08125 ]
#  [2.       0.167708 0.2375   0.05625  0.04375 ]
#  [2.       0.753125 0.632812 0.16875  0.234375]
#  [2.       0.34375  0.379688 0.091667 0.0875  ]
#  [4.       0.433333 0.635938 0.066667 0.11875 ]
#  [2.       0.215625 0.254688 0.052083 0.05    ]]

# %%
sample_img, sample_target = train_dataset[0]
print(type(sample_img))
print(sample_target)
# Out:
# Index: 0, Boxes: [[56, 206, 110, 332], [138, 70, 154, 94]]
# Index: 0
# Image Shape: (3, 416, 416)
# Boxes: [(299.0836218122902, 200.89310166832007, 365.6186522631546, 324.31438890102083), (290.046717921782, 69.57094543814199, 307.9926278431872, 93.83755055752904)]
# Labels: [2, 2]
# <class 'torch.Tensor'>
# {'boxes': tensor([[299.0836, 200.8931, 365.6187, 324.3144],
#         [290.0467,  69.5709, 307.9926,  93.8375]]), 'labels': tensor([2, 2]), 'image_id': tensor(0)}

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
from torchvision.transforms import functional as F
import matplotlib.patches as patches
import matplotlib.pyplot as plt

def display_image_with_boxes(image, boxes, class_names):
    # Convert tensor to PIL Image
    img = F.to_pil_image(image).convert("RGB")
    
    fig, ax = plt.subplots(1, figsize=(12, 9))
    ax.imshow(img)
    
    # Convert boxes tensor to numpy array
    boxes = boxes.numpy()
    
    # Ensure boxes is two-dimensional (e.g., (N, 4))
    if len(boxes.shape) == 1:
        boxes = boxes[None, :]
    
    # Iterate over boxes and add them to the display
    for i, box in enumerate(boxes):
        xmin, ymin, xmax, ymax = box
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, 
                                 linewidth=1, edgecolor='r', facecolor='none')
        ax.add_patch(rect)
        
        # Display class name above the bounding box
        label = class_names[i]
        ax.text(xmin, ymin, label, bbox={'facecolor': 'red', 'alpha': 0.5}, clip_box=ax.clipbox, clip_on=True, fontsize=10, color='white')
        
    plt.show()

# %%
type(sample_target["boxes"])
# Out:
# torch.Tensor

# %%
sample_target["boxes"].shape
# Out:
# torch.Size([2, 4])

# %%
print(sample_target["boxes"])
# Out:
# tensor([[299.0836, 200.8931, 365.6187, 324.3144],
#         [290.0467,  69.5709, 307.9926,  93.8375]])

# %%
# train_dataset = CustomDataset(images_path, labels_path, albu_transform)
# val_dataset = CustomDataset(images_path, labels_path)

# %%
sample_img, sample_target = train_dataset[10]
# Out:
# Index: 10, Boxes: [[82, 192, 122, 260], [239, 234, 265, 286]]
# Index: 10
# Image Shape: (3, 416, 416)
# Boxes: [(310.70836328328795, 176.17112265791764, 361.17525890056237, 253.98396305239675), (160.38642709119338, 238.19791745365325, 194.01333359173557, 297.2174869615998)]
# Labels: [2, 2]

# %%
boxes = sample_target['boxes']
labels = sample_target['labels']

# %%
boxes
# Out:
# tensor([[310.7084, 176.1711, 361.1753, 253.9840],
#         [160.3864, 238.1979, 194.0133, 297.2175]])

# %%
labels
# Out:
# tensor([2, 2])

# %%
labels.ndim
# Out:
# 1

# %%
class_names = [train_dataset.idx_to_class[idx.item()] for idx in labels]

# %%
class_names
# Out:
# ['car', 'car']

# %%
display_image_with_boxes(sample_img, sample_target["boxes"], class_names)

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        
        # First convolutional layer
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        # Second convolutional layer
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.batchnorm2 = nn.BatchNorm2d(32)
        
        # Third convolutional layer
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.batchnorm3 = nn.BatchNorm2d(64)
        
        # Fully connected layers
        self.fc1 = nn.Linear(173056, 512) # since my input images size are 416 * 416 
          # Assuming the input image size is 256x256
        self.fc2 = nn.Linear(512, num_classes)
        
    def forward(self, x):
        x = self.pool(F.relu(self.batchnorm1(self.conv1(x))))
        x = self.pool(F.relu(self.batchnorm2(self.conv2(x))))
        x = self.pool(F.relu(self.batchnorm3(self.conv3(x))))
         # Dynamically compute the flattened size
        flattened_size = x.shape[1] * x.shape[2] * x.shape[3]
        # Flatten the tensor
        x = x.view(-1, flattened_size)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
import torch.optim as optim

# Define the model
model = SimpleCNN(num_classes=7)
model.to(device)  # Move the model to the GPU if available

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Suitable for multi-class classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # You can adjust learning rate as necessary

# %%
training_loader= DataLoader(train_dataset, batch_size=1,shuffle=True,num_workers= 0,
                    collate_fn=collate_fn,
                    pin_memory=True if device=="cuda" else False)

# %%
testing_loader = DataLoader(test_dataset, batch_size=2,shuffle=False,num_workers=0,
                  collate_fn=collate_fn,
                  pin_memory=True if device=="cuda" else False)

# %%
sample = next(iter(training_loader))
# print(type(sample))
# print(len(sample))
(sample[1][0])
# Out:
# Index: 2337, Boxes: [[266, 244, 280, 318], [57, 101, 73, 133], [32, 78, 46, 104], [32, 148, 70, 196]]
# Index: 2337
# Image Shape: (3, 416, 416)
# Boxes: [(135.99999999999997, 244.0, 150.00000000000003, 318.0), (343.0, 101.0, 359.0, 133.0), (370.0, 78.0, 384.0, 104.0), (346.0, 148.0, 384.0, 196.0)]
# Labels: [4, 4, 4, 4]
# {'boxes': tensor([[136., 244., 150., 318.],
#          [343., 101., 359., 133.],
#          [370.,  78., 384., 104.],
#          [346., 148., 384., 196.]]),
#  'labels': tensor([4, 4, 4, 4]),
#  'image_id': tensor(2337)}

# %%
print(type(sample[1]))
# Out:
# <class 'tuple'>

# %%
print(len(sample[1]))
# Out:
# 1

# %%
sample[0]
# Out:
# (tensor([[[0.0078, 0.5205, 0.7280,  ..., 0.2935, 0.6849, 0.3288],
#           [0.0352, 0.6301, 0.7162,  ..., 0.2975, 0.6301, 0.3875],
#           [0.0822, 0.2935, 0.3836,  ..., 0.1918, 0.6419, 0.3209],
#           ...,
#           [0.1252, 0.1840, 0.2896,  ..., 0.2231, 0.2035, 0.1566],
#           [0.2114, 0.1800, 0.2818,  ..., 0.1918, 0.1918, 0.2153],
#           [0.2192, 0.2074, 0.3288,  ..., 0.1957, 0.2309, 0.2153]],
#
#          [[0.0900, 0.5166, 0.7828,  ..., 0.3953, 0.7671, 0.3836],
#           [0.0900, 0.6301, 0.7280,  ..., 0.4031, 0.7828, 0.5245],
#           [0.1174, 0.3757, 0.3914,  ..., 0.3288, 0.7241, 0.4227],
#           ...,
#           [0.1761, 0.2153, 0.2975,  ..., 0.2701, 0.2074, 0.1526],
#           [0.1918, 0.2153, 0.2935,  ..., 0.2348, 0.1918, 0.2505],
#           [0.1918, 0.2427, 0.3092,  ..., 0.2192, 0.2153, 0.2348]],
#
#          [[0.0548, 0.5088, 0.7789,  ..., 0.2857, 0.6771, 0.3014],
#           [0.0548, 0.6810, 0.7671,  ..., 0.2231, 0.6223, 0.3405],
#           [0.0939, 0.2935, 0.3914,  ..., 0.1605, 0.5675, 0.2701],
#           ...,
#           [0.1722, 0.2309, 0.2740,  ..., 0.2387, 0.2114, 0.2622],
#           [0.1840, 0.2622, 0.3092,  ..., 0.2544, 0.2975, 0.2114],
#           [0.2153, 0.2701, 0.3640,  ..., 0.2153, 0.2348, 0.2153]]]),)

# %%
sample[1]
# Out:
# ({'boxes': tensor([[136., 244., 150., 318.],
#           [343., 101., 359., 133.],
#           [370.,  78., 384., 104.],
#           [346., 148., 384., 196.]]),
#   'labels': tensor([4, 4, 4, 4]),
#   'image_id': tensor(2337)},)

# %%
sample[1][0]['boxes']
# Out:
# tensor([[136., 244., 150., 318.],
#         [343., 101., 359., 133.],
#         [370.,  78., 384., 104.],
#         [346., 148., 384., 196.]])

# %%
(sample[0])
# Out:
# (tensor([[[0.0078, 0.5205, 0.7280,  ..., 0.2935, 0.6849, 0.3288],
#           [0.0352, 0.6301, 0.7162,  ..., 0.2975, 0.6301, 0.3875],
#           [0.0822, 0.2935, 0.3836,  ..., 0.1918, 0.6419, 0.3209],
#           ...,
#           [0.1252, 0.1840, 0.2896,  ..., 0.2231, 0.2035, 0.1566],
#           [0.2114, 0.1800, 0.2818,  ..., 0.1918, 0.1918, 0.2153],
#           [0.2192, 0.2074, 0.3288,  ..., 0.1957, 0.2309, 0.2153]],
#
#          [[0.0900, 0.5166, 0.7828,  ..., 0.3953, 0.7671, 0.3836],
#           [0.0900, 0.6301, 0.7280,  ..., 0.4031, 0.7828, 0.5245],
#           [0.1174, 0.3757, 0.3914,  ..., 0.3288, 0.7241, 0.4227],
#           ...,
#           [0.1761, 0.2153, 0.2975,  ..., 0.2701, 0.2074, 0.1526],
#           [0.1918, 0.2153, 0.2935,  ..., 0.2348, 0.1918, 0.2505],
#           [0.1918, 0.2427, 0.3092,  ..., 0.2192, 0.2153, 0.2348]],
#
#          [[0.0548, 0.5088, 0.7789,  ..., 0.2857, 0.6771, 0.3014],
#           [0.0548, 0.6810, 0.7671,  ..., 0.2231, 0.6223, 0.3405],
#           [0.0939, 0.2935, 0.3914,  ..., 0.1605, 0.5675, 0.2701],
#           ...,
#           [0.1722, 0.2309, 0.2740,  ..., 0.2387, 0.2114, 0.2622],
#           [0.1840, 0.2622, 0.3092,  ..., 0.2544, 0.2975, 0.2114],
#           [0.2153, 0.2701, 0.3640,  ..., 0.2153, 0.2348, 0.2153]]]),)

# %%
ibo = sample[0]

# %%
plt.imshow(ibo[0].permute(1, 2, 0)) # extreacting tesnor from tuple

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from torchvision.transforms import ToTensor
# transform = ToTensor()

# for batch_idx, (imgs, targets) in enumerate(training_loader):
#     for i, (img, target) in enumerate(zip(imgs, targets)):
#         if isinstance(img, Image.Image):
#             img_tensor = transform(img).to(device)
#         else:
#             img_tensor = img.to(device)

#         target['boxes'] = target['boxes'].to(device)
#         target['labels'] = target['labels'].to(device)
#         target['image_id'] = target['image_id'].to(device)

# %%
## Inspecting code
for batch_idx, (imgs, targets) in enumerate(training_loader):
    print((f"the length is {(targets[0])}"))
# Out:
# Index: 4050, Boxes: [[153, 144, 191, 230], [186, 21, 196, 39]]
# Index: 4050
# Image Shape: (3, 416, 416)
# Boxes: [(165.37206601177087, 142.70509190877937, 213.03771488882103, 235.87750396322963), (188.20996954667893, 14.07908340954741, 200.31881067738757, 33.77238506982274)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[165.3721, 142.7051, 213.0377, 235.8775],
#         [188.2100,  14.0791, 200.3188,  33.7724]]), 'labels': tensor([2, 2]), 'image_id': tensor(4050)}
# Index: 3122, Boxes: [[243, 238, 269, 304]]
# Index: 3122
# Image Shape: (3, 416, 416)
# Boxes: [(226.50771698471004, 212.46082030158863, 251.48328668797086, 272.55368751422526)]
# Labels: [0]
# the length is {'boxes': tensor([[226.5077, 212.4608, 251.4833, 272.5537]]), 'labels': tensor([0]), 'image_id': tensor(3122)}
# Index: 2267, Boxes: [[199, 124, 217, 154], [200, 81, 212, 101], [122, 115, 144, 149], [82, 139, 108, 179]]
# Index: 2267
# Image Shape: (3, 416, 416)
# Boxes: [(182.80169091584654, 128.05527298135695, 204.52975041262678, 162.1558476886685), (187.39818136616364, 80.94730096442603, 201.88355436401713, 103.68101743596708), (98.657454960129, 113.09758127003012, 125.03790064058356, 151.850542161016), (52.79386118192403, 136.78618279743165, 83.95874665776054, 182.38566935222138)]
# Labels: [4, 4, 4, 4]
# the length is {'boxes': tensor([[182.8017, 128.0553, 204.5298, 162.1559],
#         [187.3982,  80.9473, 201.8836, 103.6810],
#         [ 98.6575, 113.0976, 125.0379, 151.8505],
#         [ 52.7939, 136.7862,  83.9587, 182.3857]]), 'labels': tensor([4, 4, 4, 4]), 'image_id': tensor(2267)}
# Index: 4235, Boxes: [[204, 58, 238, 152], [59, 99, 75, 133]]
# Index: 4235
# Image Shape: (3, 416, 416)
# Boxes: [(189.05056417287554, 67.08511976390258, 249.54666218029752, 174.28907223589175), (364.3242441680625, 153.23477878403997, 390.0719821076375, 192.99487306298505)]
# Labels: [3, 3]
# the length is {'boxes': tensor([[189.0506,  67.0851, 249.5467, 174.2891],
#         [364.3242, 153.2348, 390.0720, 192.9949]]), 'labels': tensor([3, 3]), 'image_id': tensor(4235)}
# Index: 5657, Boxes: [[199, 165, 253, 271], [133, 78, 149, 112]]
# Index: 5657
# Image Shape: (3, 416, 416)
# Boxes: [(163.00000000000003, 165.0, 217.0, 271.0), (267.0, 78.0, 283.0, 112.0)]
# Labels: [7, 7]
# the length is {'boxes': tensor([[163., 165., 217., 271.],
#         [267.,  78., 283., 112.]]), 'labels': tensor([7, 7]), 'image_id': tensor(5657)}
# Index: 2736, Boxes: [[217, 171, 243, 225], [104, 114, 150, 200], [223, 131, 237, 157], [201, 81, 211, 103]]
# Index: 2736
# Image Shape: (3, 416, 416)
# Boxes: [(149.7598408739704, 164.16643971958075, 180.99325211784745, 219.6519465852917), (243.16401623487562, 118.71722587861146, 297.3841982311186, 207.58325876318864), (163.01680606119587, 125.81730536050117, 179.4996579553427, 152.6939125211483), (194.2502173050729, 79.89590930014549, 206.3971232937404, 102.43657055531321)]
# Labels: [2, 2, 2, 2]
# the length is {'boxes': tensor([[149.7598, 164.1664, 180.9933, 219.6519],
#         [243.1640, 118.7172, 297.3842, 207.5833],
#         [163.0168, 125.8173, 179.4997, 152.6939],
#         [194.2502,  79.8959, 206.3971, 102.4366]]), 'labels': tensor([2, 2, 2, 2]), 'image_id': tensor(2736)}
# Index: 2417, Boxes: [[148, 380, 214, 492], [416, 225, 580, 567], [353, 57, 375, 97], [417, 145, 437, 195], [223, 142, 243, 188]]
# Index: 2417
# Image Shape: (3, 416, 416)
# Boxes: [(96.2, 247.0, 139.1, 319.8), (270.40000000000003, 146.25, 377.0, 368.55), (229.45, 37.050000000000004, 243.75, 63.05), (271.05, 94.25, 284.05, 126.75), (144.95000000000002, 92.3, 157.95000000000002, 122.2)]
# Labels: [2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[ 96.2000, 247.0000, 139.1000, 319.8000],
#         [270.4000, 146.2500, 377.0000, 368.5500],
#         [229.4500,  37.0500, 243.7500,  63.0500],
#         [271.0500,  94.2500, 284.0500, 126.7500],
#         [144.9500,  92.3000, 157.9500, 122.2000]]), 'labels': tensor([2, 2, 2, 2, 2]), 'image_id': tensor(2417)}
# Index: 2577, Boxes: [[205, 122, 219, 158], [225, 126, 277, 250]]
# Index: 2577
# Image Shape: (3, 416, 416)
# Boxes: [(185.0427275510715, 131.50999746783543, 208.37997017826524, 172.13389958058804), (126.14523466184934, 140.57461421067384, 210.42958842778575, 281.43348992934847)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[185.0427, 131.5100, 208.3800, 172.1339],
#         [126.1452, 140.5746, 210.4296, 281.4335]]), 'labels': tensor([2, 2]), 'image_id': tensor(2577)}
# Index: 1002, Boxes: [[192, 137, 220, 187], [205, 84, 213, 98]]
# Index: 1002
# Image Shape: (3, 416, 416)
# Boxes: [(179.9558454145602, 139.50070415157228, 216.57907477775214, 197.1996079867742), (187.3841947640126, 82.94821134102999, 197.81207845140244, 99.1240062480589)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[179.9558, 139.5007, 216.5791, 197.1996],
#         [187.3842,  82.9482, 197.8121,  99.1240]]), 'labels': tensor([2, 2]), 'image_id': tensor(1002)}
# Index: 1633, Boxes: [[236, 241, 272, 343], [166, 159, 220, 279], [322, 218, 342, 266], [42, 165, 54, 199], [151, 109, 167, 125], [232, 112, 242, 134]]
# Index: 1633
# Image Shape: (3, 416, 416)
# Boxes: [(139.38981988153986, 257.11650648069934, 177.0177482510635, 356.46744693093433), (191.34946588935796, 179.5692897668413, 246.84420323537185, 296.7870391935666), (74.12693090072175, 232.93771638077703, 94.78258771798171, 279.77889347470244), (353.6528047964443, 190.11716043547287, 366.19544758628547, 223.23414058555122), (246.85616129090533, 132.89553714887248, 262.73776927000785, 148.77714512797496), (174.30543430540567, 133.63460815267598, 184.57585936807985, 155.12739904820677)]
# Labels: [2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[139.3898, 257.1165, 177.0177, 356.4674],
#         [191.3495, 179.5693, 246.8442, 296.7870],
#         [ 74.1269, 232.9377,  94.7826, 279.7789],
#         [353.6528, 190.1172, 366.1954, 223.2341],
#         [246.8562, 132.8955, 262.7378, 148.7771],
#         [174.3054, 133.6346, 184.5759, 155.1274]]), 'labels': tensor([2, 2, 2, 2, 2, 2]), 'image_id': tensor(1633)}
# Index: 4675, Boxes: [[111, 92, 159, 186], [170, 116, 188, 148]]
# Index: 4675
# Image Shape: (3, 416, 416)
# Boxes: [(111.0, 92.0, 159.0, 186.0), (170.0, 116.0, 188.0, 148.0)]
# Labels: [5, 5]
# the length is {'boxes': tensor([[111.,  92., 159., 186.],
#         [170., 116., 188., 148.]]), 'labels': tensor([5, 5]), 'image_id': tensor(4675)}
# Index: 881, Boxes: [[108, 32, 134, 90], [197, 80, 211, 98]]
# Index: 881
# Image Shape: (3, 416, 416)
# Boxes: [(128.36729733282343, 3.0677551493990602, 164.54829577290118, 70.29037526040835), (225.27007126496028, 67.50490520395219, 243.02589725359127, 89.1409339014496)]
# Labels: [3, 3]
# the length is {'boxes': tensor([[128.3673,   3.0678, 164.5483,  70.2904],
#         [225.2701,  67.5049, 243.0259,  89.1409]]), 'labels': tensor([3, 3]), 'image_id': tensor(881)}
# Index: 1317, Boxes: [[213, 186, 273, 342]]
# Index: 1317
# Image Shape: (3, 416, 416)
# Boxes: [(130.65326633165827, 194.41206030150755, 193.36683417085425, 357.46733668341705)]
# Labels: [7]
# the length is {'boxes': tensor([[130.6533, 194.4121, 193.3668, 357.4673]]), 'labels': tensor([7]), 'image_id': tensor(1317)}
# Index: 4877, Boxes: [[105, 114, 153, 186]]
# Index: 4877
# Image Shape: (3, 416, 416)
# Boxes: [(259.231527093596, 116.807881773399, 308.4137931034483, 190.58128078817734)]
# Labels: [2]
# the length is {'boxes': tensor([[259.2315, 116.8079, 308.4138, 190.5813]]), 'labels': tensor([2]), 'image_id': tensor(4877)}
# Index: 3875, Boxes: [[190, 162, 224, 248], [136, 22, 172, 90], [199, 51, 213, 77], [186, 54, 202, 76], [334, 188, 350, 234]]
# Index: 3875
# Image Shape: (3, 416, 416)
# Boxes: [(192.0, 162.0, 226.00000000000003, 248.0), (244.0, 22.0, 280.0, 90.0), (203.00000000000003, 51.0, 217.0, 77.0), (213.99999999999997, 54.00000000000001, 230.0, 76.0), (66.0, 188.0, 81.99999999999999, 234.0)]
# Labels: [2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[192., 162., 226., 248.],
#         [244.,  22., 280.,  90.],
#         [203.,  51., 217.,  77.],
#         [214.,  54., 230.,  76.],
#         [ 66., 188.,  82., 234.]]), 'labels': tensor([2, 2, 2, 2, 2]), 'image_id': tensor(3875)}
# Index: 4745, Boxes: [[106, 149, 134, 197], [202, 143, 226, 191], [254, 270, 276, 328], [32, 111, 56, 143], [65, 84, 93, 124], [82, 68, 98, 88]]
# Index: 4745
# Image Shape: (3, 416, 416)
# Boxes: [(277.71762772029217, 155.10618295365018, 305.9345181448754, 202.67087184373818), (187.26068488236626, 150.63996882924735, 211.5485433731708, 198.14518547865765), (140.03602935165034, 276.15987185553035, 162.50805247725987, 333.4579322190485), (353.76876414253786, 116.68014313021509, 377.8187336706316, 148.46923204451073), (317.02378113051066, 90.64982356280025, 345.12172707373844, 130.35644858533095), (311.87460225057646, 75.18645285056587, 327.88809118907966, 95.06950148217007)]
# Labels: [2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[277.7176, 155.1062, 305.9345, 202.6709],
#         [187.2607, 150.6400, 211.5485, 198.1452],
#         [140.0360, 276.1599, 162.5081, 333.4579],
#         [353.7688, 116.6801, 377.8187, 148.4692],
#         [317.0238,  90.6498, 345.1217, 130.3564],
#         [311.8746,  75.1865, 327.8881,  95.0695]]), 'labels': tensor([2, 2, 2, 2, 2, 2]), 'image_id': tensor(4745)}
# Index: 3955, Boxes: [[109, 185, 139, 247], [99, 131, 119, 169], [148, 43, 164, 65], [240, 157, 256, 183], [206, 77, 214, 97], [16, 86, 82, 180]]
# Index: 3955
# Image Shape: (3, 416, 416)
# Boxes: [(109.0, 185.0, 139.0, 247.0), (99.0, 131.0, 119.0, 169.0), (148.0, 43.0, 164.0, 65.0), (239.99999999999997, 157.0, 256.0, 183.0), (206.0, 77.0, 213.99999999999997, 97.0), (16.0, 86.0, 82.0, 180.0)]
# Labels: [2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[109., 185., 139., 247.],
#         [ 99., 131., 119., 169.],
#         [148.,  43., 164.,  65.],
#         [240., 157., 256., 183.],
#         [206.,  77., 214.,  97.],
#         [ 16.,  86.,  82., 180.]]), 'labels': tensor([2, 2, 2, 2, 2, 2]), 'image_id': tensor(3955)}
# Index: 2001, Boxes: [[269, 276, 333, 372], [102, 57, 126, 97], [7, 69, 29, 105], [227, 89, 251, 133]]
# Index: 2001
# Image Shape: (3, 416, 416)
# Boxes: [(171.8745439007166, 189.65620265760938, 227.19505413473, 262.4265987172021), (94.59195079190137, 20.968514707663708, 115.84766059422779, 50.94916742277977), (29.641751784499956, 16.918963752400057, 49.0410660258706, 43.952603042461654), (174.11460313478364, 58.45625026766926, 195.8808314016814, 91.12865717555414)]
# Labels: [2, 2, 2, 2]
# the length is {'boxes': tensor([[171.8745, 189.6562, 227.1951, 262.4266],
#         [ 94.5919,  20.9685, 115.8477,  50.9492],
#         [ 29.6418,  16.9190,  49.0411,  43.9526],
#         [174.1146,  58.4562, 195.8808,  91.1287]]), 'labels': tensor([2, 2, 2, 2]), 'image_id': tensor(2001)}
# Index: 6289, Boxes: [[69, 152, 109, 212], [268, 328, 300, 392], [155, 44, 175, 72]]
# Index: 6289
# Image Shape: (3, 416, 416)
# Boxes: [(69.0, 152.0, 109.0, 212.0), (268.0, 328.0, 300.0, 392.0), (155.0, 44.0, 175.0, 72.0)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[ 69., 152., 109., 212.],
#         [268., 328., 300., 392.],
#         [155.,  44., 175.,  72.]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(6289)}
# Index: 411, Boxes: [[117, 99, 205, 409], [142, 69, 158, 97], [37, 116, 47, 150], [96, 79, 104, 109]]
# Index: 411
# Image Shape: (3, 416, 416)
# Boxes: [(190.0994985720613, 105.02689969087633, 300.19156093755834, 416.0), (256.5177169212839, 75.43975955691081, 275.05865656554187, 106.16936859699939), (372.2807285165673, 131.39967176037842, 384.7273334629099, 168.22361549838234), (313.55204690462, 88.92699198044296, 323.6550187085006, 121.37585767667976)]
# Labels: [5, 5, 5, 5]
# the length is {'boxes': tensor([[190.0995, 105.0269, 300.1916, 416.0000],
#         [256.5177,  75.4398, 275.0587, 106.1694],
#         [372.2807, 131.3997, 384.7273, 168.2236],
#         [313.5520,  88.9270, 323.6550, 121.3759]]), 'labels': tensor([5, 5, 5, 5]), 'image_id': tensor(411)}
# Index: 4832, Boxes: [[50, 169, 100, 241], [247, 244, 263, 282]]
# Index: 4832
# Image Shape: (3, 416, 416)
# Boxes: [(291.03379301170907, 104.02675448714763, 361.9134786309064, 191.75332800635027), (142.70518743113985, 234.12190634640748, 169.38312870029128, 277.64673551556416)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[291.0338, 104.0268, 361.9135, 191.7533],
#         [142.7052, 234.1219, 169.3831, 277.6467]]), 'labels': tensor([2, 2]), 'image_id': tensor(4832)}
# Index: 1546, Boxes: [[198, 110, 296, 346], [185, 6, 207, 52], [230, 31, 242, 53]]
# Index: 1546
# Image Shape: (3, 416, 416)
# Boxes: [(72.41218368372684, 84.00468731438198, 210.8544367884877, 328.8714353862714), (213.13648267044235, 0.9774219862696611, 242.90165792195222, 49.251205058149694), (179.3688474767828, 18.375023061483134, 195.0226270950532, 41.74072260490773)]
# Labels: [5, 5, 5]
# the length is {'boxes': tensor([[ 72.4122,  84.0047, 210.8544, 328.8714],
#         [213.1365,   0.9774, 242.9017,  49.2512],
#         [179.3689,  18.3750, 195.0226,  41.7407]]), 'labels': tensor([5, 5, 5]), 'image_id': tensor(1546)}
# Index: 4509, Boxes: [[188, 79, 216, 147]]
# Index: 4509
# Image Shape: (3, 416, 416)
# Boxes: [(162.97434844521257, 64.2239554683735, 194.27983696939035, 137.94423212081958)]
# Labels: [2]
# the length is {'boxes': tensor([[162.9743,  64.2240, 194.2798, 137.9442]]), 'labels': tensor([2]), 'image_id': tensor(4509)}
# Index: 5405, Boxes: [[111, 160, 139, 212], [36, 94, 46, 122], [202, 205, 236, 271], [240, 201, 260, 255], [198, 90, 218, 120], [151, 15, 167, 43]]
# Index: 5405
# Image Shape: (3, 416, 416)
# Boxes: [(111.0, 160.0, 139.0, 212.0), (36.0, 94.0, 46.0, 122.0), (202.0, 205.0, 236.0, 271.0), (239.99999999999997, 201.0, 260.0, 255.00000000000003), (198.0, 90.0, 218.0, 119.99999999999999), (151.0, 14.999999999999998, 167.0, 43.0)]
# Labels: [2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[111., 160., 139., 212.],
#         [ 36.,  94.,  46., 122.],
#         [202., 205., 236., 271.],
#         [240., 201., 260., 255.],
#         [198.,  90., 218., 120.],
#         [151.,  15., 167.,  43.]]), 'labels': tensor([2, 2, 2, 2, 2, 2]), 'image_id': tensor(5405)}
# Index: 3451, Boxes: [[169, 159, 223, 321]]
# Index: 3451
# Image Shape: (3, 416, 416)
# Boxes: [(169.0, 159.0, 223.0, 321.0)]
# Labels: [1]
# the length is {'boxes': tensor([[169., 159., 223., 321.]]), 'labels': tensor([1]), 'image_id': tensor(3451)}
# Index: 1408, Boxes: [[79, 186, 109, 258], [195, 69, 211, 91]]
# Index: 1408
# Image Shape: (3, 416, 416)
# Boxes: [(71.89287993799871, 174.97924643445677, 103.7912081794684, 248.30799049754356), (186.29714293750396, 54.61660086204961, 202.93894883330725, 77.17703758951247)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[ 71.8929, 174.9792, 103.7912, 248.3080],
#         [186.2971,  54.6166, 202.9389,  77.1770]]), 'labels': tensor([2, 2]), 'image_id': tensor(1408)}
# Index: 2946, Boxes: [[176, 1, 208, 95], [4, 49, 106, 257]]
# Index: 2946
# Image Shape: (3, 416, 416)
# Boxes: [(208.0, 1.0, 239.99999999999997, 95.0), (310.0, 49.0, 412.0, 257.0)]
# Labels: [7, 7]
# the length is {'boxes': tensor([[208.,   1., 240.,  95.],
#         [310.,  49., 412., 257.]]), 'labels': tensor([7, 7]), 'image_id': tensor(2946)}
# Index: 4994, Boxes: [[460, 390, 530, 546], [350, 85, 400, 223]]
# Index: 4994
# Image Shape: (3, 416, 416)
# Boxes: [(299.0, 253.5, 344.5, 354.90000000000003), (227.5, 55.25, 260.0, 144.95000000000002)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[299.0000, 253.5000, 344.5000, 354.9000],
#         [227.5000,  55.2500, 260.0000, 144.9500]]), 'labels': tensor([2, 2]), 'image_id': tensor(4994)}
# Index: 379, Boxes: [[77, 284, 113, 346], [102, 121, 122, 157], [121, 72, 137, 100], [198, 146, 214, 184], [186, 81, 196, 97], [187, 61, 203, 77], [161, 65, 179, 87]]
# Index: 379
# Image Shape: (3, 416, 416)
# Boxes: [(132.97762756694038, 291.77435806127585, 178.42860766626956, 354.92551457747516), (120.5058034162142, 144.0506890212351, 146.0887771780975, 180.52607903965378), (127.02941194877123, 97.01557458849354, 147.32482733768907, 125.48030216981299), (211.71854856947857, 146.75188619776225, 234.15100921575603, 184.16141919677597), (187.09398789540785, 92.4573324459966, 199.45806572487754, 108.90606637166712), (183.71437792245803, 73.07178993045626, 201.44533900254433, 90.80275101054255), (161.3127019393967, 81.77862071519709, 182.1148512574376, 105.30387409737187)]
# Labels: [2, 2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[132.9776, 291.7744, 178.4286, 354.9255],
#         [120.5058, 144.0507, 146.0888, 180.5261],
#         [127.0294,  97.0156, 147.3248, 125.4803],
#         [211.7186, 146.7519, 234.1510, 184.1614],
#         [187.0940,  92.4573, 199.4581, 108.9061],
#         [183.7144,  73.0718, 201.4453,  90.8027],
#         [161.3127,  81.7786, 182.1149, 105.3039]]), 'labels': tensor([2, 2, 2, 2, 2, 2, 2]), 'image_id': tensor(379)}
# Index: 5489, Boxes: [[230, 217, 256, 271], [201, 117, 239, 189], [265, 306, 287, 366], [124, 69, 148, 97], [27, 124, 57, 166]]
# Index: 5489
# Image Shape: (3, 416, 416)
# Boxes: [(150.51241653403173, 234.92218886185492, 176.5232389867434, 287.2531378410157), (168.43624074644583, 139.29213058166857, 206.31613178622834, 209.1321752607107), (118.89841613308826, 319.7213521340139, 141.1884881346896, 377.7315958500818), (257.569639562249, 95.01616759726244, 281.150706240004, 122.35725235022448), (343.5419946382717, 149.58295269041446, 373.1557646698038, 190.4767769475676)]
# Labels: [2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[150.5124, 234.9222, 176.5232, 287.2531],
#         [168.4362, 139.2921, 206.3161, 209.1322],
#         [118.8984, 319.7213, 141.1885, 377.7316],
#         [257.5696,  95.0162, 281.1507, 122.3573],
#         [343.5420, 149.5829, 373.1558, 190.4768]]), 'labels': tensor([2, 2, 2, 2, 2]), 'image_id': tensor(5489)}
# Index: 6291, Boxes: [[82, 134, 116, 182], [196, 152, 224, 198], [147, 32, 159, 48], [246, 170, 262, 204]]
# Index: 6291
# Image Shape: (3, 416, 416)
# Boxes: [(82.0, 134.0, 116.0, 182.0), (196.0, 152.0, 224.0, 198.0), (147.0, 32.0, 159.0, 48.0), (246.0, 170.0, 262.0, 204.0)]
# Labels: [2, 2, 2, 2]
# the length is {'boxes': tensor([[ 82., 134., 116., 182.],
#         [196., 152., 224., 198.],
#         [147.,  32., 159.,  48.],
#         [246., 170., 262., 204.]]), 'labels': tensor([2, 2, 2, 2]), 'image_id': tensor(6291)}
# Index: 2892, Boxes: [[97, 118, 113, 160], [113, 141, 143, 193], [157, 101, 165, 129], [50, 97, 72, 125], [84, 74, 100, 98]]
# Index: 2892
# Image Shape: (3, 416, 416)
# Boxes: [(122.41696152692326, 99.16196393881017, 145.41009919409834, 142.566736728677), (131.92027405897807, 124.23311946376153, 170.22103622007182, 179.80526519020984), (185.88838938426034, 93.55006123092943, 198.64400856379245, 122.00693819714746), (83.36063370659205, 70.44486847361424, 109.62523402869346, 101.41984613172139), (121.02449638718932, 54.36692970540972, 140.78007602193554, 80.40301245483032)]
# Labels: [2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[122.4170,  99.1620, 145.4101, 142.5667],
#         [131.9203, 124.2331, 170.2210, 179.8053],
#         [185.8884,  93.5501, 198.6440, 122.0069],
#         [ 83.3606,  70.4449, 109.6252, 101.4198],
#         [121.0245,  54.3669, 140.7801,  80.4030]]), 'labels': tensor([2, 2, 2, 2, 2]), 'image_id': tensor(2892)}
# Index: 989, Boxes: [[132, 47, 192, 301]]
# Index: 989
# Image Shape: (3, 416, 416)
# Boxes: [(202.5138898710906, 41.77985591048665, 304.9556588591323, 304.27726121993675)]
# Labels: [7]
# the length is {'boxes': tensor([[202.5139,  41.7799, 304.9557, 304.2773]]), 'labels': tensor([7]), 'image_id': tensor(989)}
# Index: 4928, Boxes: [[82, 162, 110, 208], [200, 141, 240, 243], [261, 242, 277, 296]]
# Index: 4928
# Image Shape: (3, 416, 416)
# Boxes: [(293.39181051721897, 202.1939798530388, 331.6600326689426, 255.198439092689), (152.74781259660938, 153.68922772445808, 214.94117516303007, 266.64074026040345), (103.79359369949194, 249.64740419021194, 131.40818824224039, 308.3718325852496)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[293.3918, 202.1940, 331.6600, 255.1984],
#         [152.7478, 153.6892, 214.9412, 266.6407],
#         [103.7936, 249.6474, 131.4082, 308.3718]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(4928)}
# Index: 1579, Boxes: [[221, 275, 261, 367], [199, 120, 219, 150], [38, 88, 50, 114], [206, 99, 218, 117], [192, 69, 202, 91]]
# Index: 1579
# Image Shape: (3, 416, 416)
# Boxes: [(211.52506126213217, 237.04906758287098, 267.27880758211666, 331.5068644672217), (160.31157554355065, 99.4395717535838, 185.03918812996585, 131.61027098699253), (2.4899248581822775, 102.58723814445783, 18.901122696819925, 129.4187572888864), (162.7661331945662, 79.87251407792618, 177.6027007464153, 99.17493361797142), (143.68534531143848, 54.787651135065744, 157.42695310558602, 77.46096290560551)]
# Labels: [2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[211.5251, 237.0491, 267.2788, 331.5069],
#         [160.3116,  99.4396, 185.0392, 131.6103],
#         [  2.4899, 102.5872,  18.9011, 129.4188],
#         [162.7661,  79.8725, 177.6027,  99.1749],
#         [143.6853,  54.7877, 157.4270,  77.4610]]), 'labels': tensor([2, 2, 2, 2, 2]), 'image_id': tensor(1579)}
# Index: 4219, Boxes: [[192, 113, 230, 201]]
# Index: 4219
# Image Shape: (3, 416, 416)
# Boxes: [(191.67472927662635, 101.67802498175857, 243.63055945285555, 192.9594810975393)]
# Labels: [6]
# the length is {'boxes': tensor([[191.6747, 101.6780, 243.6306, 192.9595]]), 'labels': tensor([6]), 'image_id': tensor(4219)}
# Index: 1462, Boxes: [[201, 91, 217, 119], [217, 119, 231, 147], [140, 54, 156, 76], [43, 89, 53, 111], [28, 90, 36, 112]]
# Index: 1462
# Image Shape: (3, 416, 416)
# Boxes: [(201.0, 91.0, 217.0, 119.0), (217.0, 119.0, 231.0, 147.0), (140.0, 54.00000000000001, 156.0, 76.0), (43.0, 89.0, 53.0, 111.0), (28.0, 90.0, 36.0, 112.0)]
# Labels: [2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[201.,  91., 217., 119.],
#         [217., 119., 231., 147.],
#         [140.,  54., 156.,  76.],
#         [ 43.,  89.,  53., 111.],
#         [ 28.,  90.,  36., 112.]]), 'labels': tensor([2, 2, 2, 2, 2]), 'image_id': tensor(1462)}
# Index: 1207, Boxes: [[74, 168, 142, 308]]
# Index: 1207
# Image Shape: (3, 416, 416)
# Boxes: [(74.0, 168.0, 142.0, 308.0)]
# Labels: [7]
# the length is {'boxes': tensor([[ 74., 168., 142., 308.]]), 'labels': tensor([7]), 'image_id': tensor(1207)}
# Index: 1068, Boxes: [[137, 236, 205, 396], [142, 145, 180, 227], [364, 346, 386, 414]]
# Index: 1068
# Image Shape: (3, 416, 416)
# Boxes: [(79.12330560876676, 120.43441028124818, 136.32000583842253, 226.92173497271827), (97.64873564931843, 63.84732996574142, 128.93659059135473, 118.70896182429763), (219.77668837050294, 210.0602400512526, 239.76008980527158, 254.68895371692844)]
# Labels: [1, 1, 1]
# the length is {'boxes': tensor([[ 79.1233, 120.4344, 136.3200, 226.9217],
#         [ 97.6487,  63.8473, 128.9366, 118.7090],
#         [219.7767, 210.0602, 239.7601, 254.6889]]), 'labels': tensor([1, 1, 1]), 'image_id': tensor(1068)}
# Index: 1686, Boxes: [[91, 85, 145, 183]]
# Index: 1686
# Image Shape: (3, 416, 416)
# Boxes: [(77.47799051901606, 104.08426874310449, 148.68529260684085, 213.0941415653448)]
# Labels: [1]
# the length is {'boxes': tensor([[ 77.4780, 104.0843, 148.6853, 213.0941]]), 'labels': tensor([1]), 'image_id': tensor(1686)}
# Index: 3221, Boxes: [[387, 200, 499, 486], [353, 111, 379, 149], [568, 374, 640, 540], [503, 333, 573, 503]]
# Index: 3221
# Image Shape: (3, 416, 416)
# Boxes: [(251.55, 130.0, 324.34999999999997, 315.90000000000003), (229.45, 72.14999999999999, 246.35, 96.85000000000001), (369.2, 243.1, 416.0, 351.0), (326.95, 216.45, 372.45, 326.95)]
# Labels: [1, 1, 1, 1]
# the length is {'boxes': tensor([[251.5500, 130.0000, 324.3500, 315.9000],
#         [229.4500,  72.1500, 246.3500,  96.8500],
#         [369.2000, 243.1000, 416.0000, 351.0000],
#         [326.9500, 216.4500, 372.4500, 326.9500]]), 'labels': tensor([1, 1, 1, 1]), 'image_id': tensor(3221)}
# Index: 3517, Boxes: [[230, 216, 246, 246], [194, 190, 222, 226], [56, 241, 104, 315], [153, 49, 175, 85], [132, 34, 158, 82]]
# Index: 3517
# Image Shape: (3, 416, 416)
# Boxes: [(161.43283582089552, 223.52238805970148, 177.99004975124382, 254.56716417910448), (186.2686567164179, 196.61691542288557, 215.24378109452735, 233.87064676616916), (308.37810945273634, 249.39303482587064, 358.0497512437811, 325.97014925373134), (234.90547263681594, 50.70646766169154, 257.6716417910448, 87.96019900497512), (252.49751243781094, 35.18407960199005, 279.4029850746268, 84.85572139303483)]
# Labels: [4, 4, 4, 4, 4]
# the length is {'boxes': tensor([[161.4328, 223.5224, 177.9901, 254.5672],
#         [186.2687, 196.6169, 215.2438, 233.8707],
#         [308.3781, 249.3930, 358.0497, 325.9702],
#         [234.9055,  50.7065, 257.6716,  87.9602],
#         [252.4975,  35.1841, 279.4030,  84.8557]]), 'labels': tensor([4, 4, 4, 4, 4]), 'image_id': tensor(3517)}
# Index: 141, Boxes: [[131, 98, 161, 156], [120, 70, 146, 108], [92, 94, 116, 134]]
# Index: 141
# Image Shape: (3, 416, 416)
# Boxes: [(139.73333333333332, 104.53333333333333, 171.73333333333332, 166.4), (128.0, 74.66666666666667, 155.73333333333335, 115.2), (98.13333333333333, 100.26666666666667, 123.73333333333333, 142.93333333333334)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[139.7333, 104.5333, 171.7333, 166.4000],
#         [128.0000,  74.6667, 155.7333, 115.2000],
#         [ 98.1333, 100.2667, 123.7333, 142.9333]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(141)}
# Index: 3264, Boxes: [[62, 186, 124, 330]]
# Index: 3264
# Image Shape: (3, 416, 416)
# Boxes: [(276.13780718869424, 180.71214971694113, 349.18070126806543, 329.52821766969373)]
# Labels: [3]
# the length is {'boxes': tensor([[276.1378, 180.7121, 349.1807, 329.5282]]), 'labels': tensor([3]), 'image_id': tensor(3264)}
# Index: 328, Boxes: [[167, 1, 181, 33], [193, 56, 211, 92], [135, 33, 183, 179]]
# Index: 328
# Image Shape: (3, 416, 416)
# Boxes: [(167.0, 1.0, 181.0, 33.0), (193.0, 56.0, 211.0, 92.0), (135.0, 33.0, 183.0, 179.0)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[167.,   1., 181.,  33.],
#         [193.,  56., 211.,  92.],
#         [135.,  33., 183., 179.]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(328)}
# Index: 4542, Boxes: [[169, 84, 177, 106], [71, 131, 143, 321]]
# Index: 4542
# Image Shape: (3, 416, 416)
# Boxes: [(206.23731722442108, 83.12995749946302, 218.07953790302258, 104.36248126519216), (72.93545255866032, 103.64477999440705, 177.7884164793426, 287.6445842208791)]
# Labels: [4, 4]
# the length is {'boxes': tensor([[206.2373,  83.1300, 218.0795, 104.3625],
#         [ 72.9355, 103.6448, 177.7884, 287.6446]]), 'labels': tensor([4, 4]), 'image_id': tensor(4542)}
# Index: 4906, Boxes: [[157, 233, 187, 285], [63, 346, 109, 432], [132, 318, 170, 394], [186, 163, 206, 197], [289, 222, 307, 264], [163, 156, 183, 192], [209, 236, 225, 282], [145, 518, 181, 636]]
# Index: 4906
# Image Shape: (3, 416, 416)
# Boxes: [(111.8354146430264, 148.40241144347033, 133.65931010634935, 182.63358750031753), (59.958984238633434, 223.55548955632221, 93.79713483392568, 279.95233213984045), (101.32516615439992, 202.44081972527553, 129.57489815084259, 252.12130911053282), (125.7380280984135, 103.60111502478638, 140.24741469613974, 126.00604381839173), (193.51678177893507, 134.36293190460935, 207.25712717765148, 161.63849249626134), (110.97231320317621, 100.61039299458412, 125.60133093436961, 124.26288752106788), (144.451570398067, 148.000768506912, 157.18361233083925, 177.65182943085375), (121.39745676482568, 326.53942177905174, 150.91187683120017, 402.29916042128934)]
# Labels: [2, 2, 2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[111.8354, 148.4024, 133.6593, 182.6336],
#         [ 59.9590, 223.5555,  93.7971, 279.9523],
#         [101.3252, 202.4408, 129.5749, 252.1213],
#         [125.7380, 103.6011, 140.2474, 126.0060],
#         [193.5168, 134.3629, 207.2571, 161.6385],
#         [110.9723, 100.6104, 125.6013, 124.2629],
#         [144.4516, 148.0008, 157.1836, 177.6518],
#         [121.3975, 326.5394, 150.9119, 402.2992]]), 'labels': tensor([2, 2, 2, 2, 2, 2, 2, 2]), 'image_id': tensor(4906)}
# Index: 3146, Boxes: [[261, 289, 283, 367], [181, 224, 215, 310], [309, 346, 335, 414], [240, 174, 254, 208], [158, 94, 172, 110]]
# Index: 3146
# Image Shape: (3, 416, 416)
# Boxes: [(248.31187918753693, 296.3320846412522, 272.67013921938997, 375.61132321986184), (169.21344130353322, 228.55038634689313, 205.89691471595953, 316.231911267022), (295.4148252693561, 355.1550643306809, 323.5290826612397, 416.0), (231.55589485004015, 179.7641928772526, 246.6215769189161, 214.44451014139875), (151.5810363601612, 96.79855076254138, 166.14592939196706, 113.32490731387429)]
# Labels: [4, 4, 4, 4, 4]
# the length is {'boxes': tensor([[248.3119, 296.3321, 272.6701, 375.6113],
#         [169.2134, 228.5504, 205.8969, 316.2319],
#         [295.4148, 355.1551, 323.5291, 416.0000],
#         [231.5559, 179.7642, 246.6216, 214.4445],
#         [151.5810,  96.7986, 166.1459, 113.3249]]), 'labels': tensor([4, 4, 4, 4, 4]), 'image_id': tensor(3146)}
# Index: 2180, Boxes: [[200, 119, 352, 389]]
# Index: 2180
# Image Shape: (3, 416, 416)
# Boxes: [(208.0, 123.75999999999999, 366.08, 404.56)]
# Labels: [5]
# the length is {'boxes': tensor([[208.0000, 123.7600, 366.0800, 404.5600]]), 'labels': tensor([5]), 'image_id': tensor(2180)}
# Index: 997, Boxes: [[2, 164, 102, 348], [122, 69, 158, 143]]
# Index: 997
# Image Shape: (3, 416, 416)
# Boxes: [(311.910247017609, 166.4558614084266, 416.0, 354.2606908376281), (266.39857394959165, 69.27526092188481, 305.83573777444985, 144.5968411820658)]
# Labels: [5, 5]
# the length is {'boxes': tensor([[311.9102, 166.4559, 416.0000, 354.2607],
#         [266.3986,  69.2753, 305.8357, 144.5968]]), 'labels': tensor([5, 5]), 'image_id': tensor(997)}
# Index: 6396, Boxes: [[202, 164, 256, 274], [62, 190, 108, 260], [218, 89, 232, 111], [224, 148, 250, 182], [166, 98, 180, 124]]
# Index: 6396
# Image Shape: (3, 416, 416)
# Boxes: [(160.0, 164.0, 213.99999999999997, 274.0), (308.0, 190.0, 354.0, 260.0), (184.0, 89.0, 198.0, 111.0), (166.0, 148.0, 192.0, 182.0), (236.0, 98.0, 250.0, 124.0)]
# Labels: [3, 3, 3, 3, 3]
# the length is {'boxes': tensor([[160., 164., 214., 274.],
#         [308., 190., 354., 260.],
#         [184.,  89., 198., 111.],
#         [166., 148., 192., 182.],
#         [236.,  98., 250., 124.]]), 'labels': tensor([3, 3, 3, 3, 3]), 'image_id': tensor(6396)}
# Index: 3331, Boxes: [[100, 79, 132, 139]]
# Index: 3331
# Image Shape: (3, 416, 416)
# Boxes: [(102.97029702970298, 81.34653465346535, 135.92079207920793, 143.12871287128712)]
# Labels: [3]
# the length is {'boxes': tensor([[102.9703,  81.3465, 135.9208, 143.1287]]), 'labels': tensor([3]), 'image_id': tensor(3331)}
# Index: 888, Boxes: [[199, 242, 249, 400], [247, 159, 255, 191], [222, 112, 230, 128]]
# Index: 888
# Image Shape: (3, 416, 416)
# Boxes: [(191.12526165700575, 251.49563140801934, 264.42113753608913, 412.61445776191294), (224.66586395617279, 170.0371535619559, 237.44763356256993, 202.3351343849775), (193.03901871064897, 128.36590536892902, 203.3102419700371, 145.14253236719202)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[191.1253, 251.4956, 264.4211, 412.6145],
#         [224.6659, 170.0372, 237.4476, 202.3351],
#         [193.0390, 128.3659, 203.3102, 145.1425]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(888)}
# Index: 708, Boxes: [[1, 181, 91, 327]]
# Index: 708
# Image Shape: (3, 416, 416)
# Boxes: [(0.0, 169.48356130080256, 82.4784751147704, 332.90149205041195)]
# Labels: [3]
# the length is {'boxes': tensor([[  0.0000, 169.4836,  82.4785, 332.9015]]), 'labels': tensor([3]), 'image_id': tensor(708)}
# Index: 1447, Boxes: [[147, 143, 183, 231], [311, 79, 357, 161]]
# Index: 1447
# Image Shape: (3, 416, 416)
# Boxes: [(241.62941116788863, 157.44845075652373, 290.46535129246655, 243.0859660610887), (73.65352951108842, 130.99124191214946, 130.32017713305746, 213.13590312026338)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[241.6294, 157.4485, 290.4654, 243.0860],
#         [ 73.6535, 130.9912, 130.3202, 213.1359]]), 'labels': tensor([2, 2]), 'image_id': tensor(1447)}
# Index: 5754, Boxes: [[121, 113, 147, 157], [190, 89, 202, 103], [128, 24, 146, 60]]
# Index: 5754
# Image Shape: (3, 416, 416)
# Boxes: [(260.79187817258884, 119.30964467005077, 288.24365482233503, 165.76649746192894), (202.72081218274113, 93.96954314720813, 215.39086294416245, 108.751269035533), (261.8477157360406, 25.34010152284264, 280.8527918781726, 63.350253807106604)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[260.7919, 119.3096, 288.2437, 165.7665],
#         [202.7208,  93.9695, 215.3909, 108.7513],
#         [261.8477,  25.3401, 280.8528,  63.3503]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(5754)}
# Index: 5107, Boxes: [[190, 85, 238, 191]]
# Index: 5107
# Image Shape: (3, 416, 416)
# Boxes: [(162.13333333333333, 90.66666666666667, 213.33333333333331, 203.73333333333332)]
# Labels: [6]
# the length is {'boxes': tensor([[162.1333,  90.6667, 213.3333, 203.7333]]), 'labels': tensor([6]), 'image_id': tensor(5107)}
# Index: 3311, Boxes: [[284, 56, 358, 170]]
# Index: 3311
# Image Shape: (3, 416, 416)
# Boxes: [(61.6201276187685, 41.43211986454207, 152.60178784283192, 171.13839154655815)]
# Labels: [1]
# the length is {'boxes': tensor([[ 61.6201,  41.4321, 152.6018, 171.1384]]), 'labels': tensor([1]), 'image_id': tensor(3311)}
# Index: 2329, Boxes: [[235, 211, 263, 277]]
# Index: 2329
# Image Shape: (3, 416, 416)
# Boxes: [(229.54312761333813, 232.95670599302247, 263.48559695300696, 300.3608947114807)]
# Labels: [0]
# the length is {'boxes': tensor([[229.5431, 232.9567, 263.4856, 300.3609]]), 'labels': tensor([0]), 'image_id': tensor(2329)}
# Index: 3549, Boxes: [[52, 169, 144, 339]]
# Index: 3549
# Image Shape: (3, 416, 416)
# Boxes: [(272.0, 169.0, 364.0, 339.0)]
# Labels: [5]
# the length is {'boxes': tensor([[272., 169., 364., 339.]]), 'labels': tensor([5]), 'image_id': tensor(3549)}
# Index: 3127, Boxes: [[124, 83, 140, 107], [234, 150, 268, 206], [109, 135, 137, 177], [82, 224, 126, 292], [201, 224, 235, 290], [156, 64, 172, 90], [203, 83, 219, 111], [96, 46, 112, 68], [159, 37, 173, 55]]
# Index: 3127
# Image Shape: (3, 416, 416)
# Boxes: [(121.35881269073693, 103.55952144505187, 142.65004510655692, 131.32120442745548), (247.2777239070003, 145.01528973414435, 293.5653842009495, 209.09668908619847), (116.9507743148464, 157.099155641493, 154.21043104253144, 205.6821008606994), (108.05601714073839, 249.95874640136782, 167.02442284837608, 328.33850380875646), (229.1462048845619, 227.2040936561391, 277.5214479991742, 301.46113903708596), (149.95447262393358, 77.54552896403348, 171.66322160388623, 107.3423411522157), (201.7464163189895, 87.06761716181268, 223.87268186307477, 118.89955855577342), (85.14294737338346, 71.75486303600569, 106.01666322507086, 97.48141681263078), (147.3706928168108, 49.86252640395678, 165.37424633445437, 71.10130520489216)]
# Labels: [2, 2, 2, 2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[121.3588, 103.5595, 142.6500, 131.3212],
#         [247.2777, 145.0153, 293.5654, 209.0967],
#         [116.9508, 157.0992, 154.2104, 205.6821],
#         [108.0560, 249.9587, 167.0244, 328.3385],
#         [229.1462, 227.2041, 277.5215, 301.4612],
#         [149.9545,  77.5455, 171.6632, 107.3423],
#         [201.7464,  87.0676, 223.8727, 118.8996],
#         [ 85.1429,  71.7549, 106.0167,  97.4814],
#         [147.3707,  49.8625, 165.3743,  71.1013]]), 'labels': tensor([2, 2, 2, 2, 2, 2, 2, 2, 2]), 'image_id': tensor(3127)}
# Index: 5220, Boxes: [[106, 89, 148, 167], [143, 175, 165, 215]]
# Index: 5220
# Image Shape: (3, 416, 416)
# Boxes: [(268.0, 89.0, 310.0, 167.0), (251.0, 175.0, 273.0, 215.00000000000003)]
# Labels: [7, 7]
# the length is {'boxes': tensor([[268.,  89., 310., 167.],
#         [251., 175., 273., 215.]]), 'labels': tensor([7, 7]), 'image_id': tensor(5220)}
# Index: 2320, Boxes: [[37, 178, 131, 446], [60, 90, 88, 136], [242, 75, 268, 123]]
# Index: 2320
# Image Shape: (3, 416, 416)
# Boxes: [(13.421833074824901, 122.52772133410625, 80.50452733243776, 301.2211735011668), (34.41847841913069, 64.86220020007686, 53.76627452970838, 95.75593678404569), (154.8168685535481, 58.37170735424754, 172.8817823893045, 90.54832621303758)]
# Labels: [7, 7, 7]
# the length is {'boxes': tensor([[ 13.4218, 122.5277,  80.5045, 301.2212],
#         [ 34.4185,  64.8622,  53.7663,  95.7559],
#         [154.8169,  58.3717, 172.8818,  90.5483]]), 'labels': tensor([7, 7, 7]), 'image_id': tensor(2320)}
# Index: 3686, Boxes: [[68, 184, 130, 312], [118, 60, 144, 92]]
# Index: 3686
# Image Shape: (3, 416, 416)
# Boxes: [(280.1206030150754, 192.321608040201, 344.9246231155779, 326.1105527638191), (265.48743718592965, 62.713567839195974, 292.66331658291455, 96.1608040201005)]
# Labels: [2, 2]
# the length is {'boxes': tensor([[280.1206, 192.3216, 344.9246, 326.1106],
#         [265.4874,  62.7136, 292.6633,  96.1608]]), 'labels': tensor([2, 2]), 'image_id': tensor(3686)}
# Index: 3079, Boxes: [[228, 164, 286, 296], [200, 109, 216, 135], [205, 95, 217, 111]]
# Index: 3079
# Image Shape: (3, 416, 416)
# Boxes: [(217.12905077150654, 178.3606659659874, 284.41192860620004, 308.3625876960472), (185.47988492003122, 133.1760583913759, 203.0472737410148, 159.21899368470628), (188.85911934222707, 119.87939530679442, 201.70078475252902, 136.1112793060351)]
# Labels: [3, 3, 3]
# the length is {'boxes': tensor([[217.1290, 178.3607, 284.4119, 308.3626],
#         [185.4799, 133.1761, 203.0473, 159.2190],
#         [188.8591, 119.8794, 201.7008, 136.1113]]), 'labels': tensor([3, 3, 3]), 'image_id': tensor(3079)}
# Index: 3026, Boxes: [[209, 183, 237, 235], [94, 179, 134, 249], [242, 162, 256, 194]]
# Index: 3026
# Image Shape: (3, 416, 416)
# Boxes: [(159.9712213898386, 170.85280097787464, 191.6252788144055, 224.9445670556005), (262.35925055506385, 173.89063706391812, 307.28593630466577, 246.86445862996874), (143.71413630495522, 148.48144057508648, 159.95191981692972, 181.54750557693023)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[159.9712, 170.8528, 191.6253, 224.9446],
#         [262.3593, 173.8906, 307.2859, 246.8645],
#         [143.7141, 148.4814, 159.9519, 181.5475]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(3026)}
# Index: 3187, Boxes: [[142, 283, 194, 415]]
# Index: 3187
# Image Shape: (3, 416, 416)
# Boxes: [(164.6991491975483, 297.2565456991611, 238.26272189836513, 416.0)]
# Labels: [2]
# the length is {'boxes': tensor([[164.6991, 297.2565, 238.2627, 416.0000]]), 'labels': tensor([2]), 'image_id': tensor(3187)}
# Index: 4785, Boxes: [[284, 268, 316, 326], [325, 326, 363, 402], [151, 185, 177, 227]]
# Index: 4785
# Image Shape: (3, 416, 416)
# Boxes: [(231.81965119305806, 167.0000693913003, 257.6577906777104, 206.32380097068952), (194.81318360854056, 198.21270623309078, 226.22751285422842, 249.3367470018556), (328.35165753607987, 129.69954678796736, 348.8189514302688, 158.46566658660979)]
# Labels: [0, 0, 0]
# the length is {'boxes': tensor([[231.8197, 167.0001, 257.6578, 206.3238],
#         [194.8132, 198.2127, 226.2275, 249.3367],
#         [328.3517, 129.6995, 348.8189, 158.4657]]), 'labels': tensor([0, 0, 0]), 'image_id': tensor(4785)}
# Index: 1415, Boxes: [[55, 173, 97, 235], [144, 135, 160, 169], [207, 128, 231, 180], [230, 218, 256, 272], [173, 106, 183, 130], [131, 61, 147, 89]]
# Index: 1415
# Image Shape: (3, 416, 416)
# Boxes: [(313.47566473544913, 167.95372971439852, 355.41458954605486, 227.33850879447502), (258.6741842917523, 129.656936262823, 275.18020945959677, 161.86423027319114), (192.56048116141181, 119.57391413497038, 217.37050574822388, 168.8081346990415), (164.78770362426658, 201.394402625537, 191.54626097820716, 252.57715595673665), (239.42724124258666, 101.70913214973183, 249.8837207688642, 124.37770966463887), (274.75576522612647, 61.9970785280144, 290.9558693836988, 88.66469524726918)]
# Labels: [2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[313.4757, 167.9537, 355.4146, 227.3385],
#         [258.6742, 129.6569, 275.1802, 161.8642],
#         [192.5605, 119.5739, 217.3705, 168.8081],
#         [164.7877, 201.3944, 191.5463, 252.5771],
#         [239.4272, 101.7091, 249.8837, 124.3777],
#         [274.7558,  61.9971, 290.9559,  88.6647]]), 'labels': tensor([2, 2, 2, 2, 2, 2]), 'image_id': tensor(1415)}
# Index: 4315, Boxes: [[250, 201, 262, 239], [151, 172, 165, 200]]
# Index: 4315
# Image Shape: (3, 416, 416)
# Boxes: [(170.04898844977134, 237.43823116157435, 188.63018146333772, 278.0559320029394), (263.70038985386776, 191.3281767954526, 282.63101931930083, 222.12461816816196)]
# Labels: [4, 4]
# the length is {'boxes': tensor([[170.0490, 237.4382, 188.6302, 278.0559],
#         [263.7004, 191.3282, 282.6310, 222.1246]]), 'labels': tensor([4, 4]), 'image_id': tensor(4315)}
# Index: 1870, Boxes: [[214, 257, 250, 339]]
# Index: 1870
# Image Shape: (3, 416, 416)
# Boxes: [(227.10204081632654, 272.734693877551, 265.3061224489796, 359.7551020408163)]
# Labels: [2]
# the length is {'boxes': tensor([[227.1020, 272.7347, 265.3061, 359.7551]]), 'labels': tensor([2]), 'image_id': tensor(1870)}
# Index: 1153, Boxes: [[200, 73, 226, 131], [235, 120, 247, 142]]
# Index: 1153
# Image Shape: (3, 416, 416)
# Boxes: [(202.4494538101565, 89.96014815033638, 228.24258151120208, 145.24461595278774), (183.6626280660494, 135.06336270081871, 195.4631671699601, 156.07994558641872)]
# Labels: [1, 1]
# the length is {'boxes': tensor([[202.4494,  89.9602, 228.2426, 145.2446],
#         [183.6626, 135.0634, 195.4632, 156.0799]]), 'labels': tensor([1, 1]), 'image_id': tensor(1153)}
# Index: 2340, Boxes: [[221, 208, 273, 358]]
# Index: 2340
# Image Shape: (3, 416, 416)
# Boxes: [(221.0, 208.0, 273.0, 358.0)]
# Labels: [0]
# the length is {'boxes': tensor([[221., 208., 273., 358.]]), 'labels': tensor([0]), 'image_id': tensor(2340)}
# Index: 5914, Boxes: [[126, 85, 166, 153], [34, 220, 76, 288]]
# Index: 5914
# Image Shape: (3, 416, 416)
# Boxes: [(157.50760067059343, 68.10371178128386, 201.05193493080628, 136.74754061269726), (58.87897768419779, 192.18006053622284, 104.35850175269607, 260.9662581351216)]
# Labels: [3, 3]
# the length is {'boxes': tensor([[157.5076,  68.1037, 201.0519, 136.7475],
#         [ 58.8790, 192.1801, 104.3585, 260.9662]]), 'labels': tensor([3, 3]), 'image_id': tensor(5914)}
# Index: 5541, Boxes: [[336, 229, 372, 295], [114, 179, 214, 415], [211, 115, 227, 137], [275, 138, 289, 160], [160, 82, 180, 116]]
# Index: 5541
# Image Shape: (3, 416, 416)
# Boxes: [(27.130998640766474, 216.8163475784275, 70.92476775040399, 287.63069809495687), (173.67493046227898, 183.8198855621142, 301.19459395171657, 416.0), (191.50330525127612, 117.5934442524578, 210.14981841350033, 141.64407369606042), (126.1865441592268, 133.96222543466976, 142.80876225861184, 157.78993190922597), (241.41493040298482, 89.43126548820163, 265.447571505166, 126.07351124693234)]
# Labels: [2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[ 27.1310, 216.8163,  70.9248, 287.6307],
#         [173.6749, 183.8199, 301.1946, 416.0000],
#         [191.5033, 117.5934, 210.1498, 141.6441],
#         [126.1865, 133.9622, 142.8088, 157.7899],
#         [241.4149,  89.4313, 265.4476, 126.0735]]), 'labels': tensor([2, 2, 2, 2, 2]), 'image_id': tensor(5541)}
# Index: 207, Boxes: [[60, 163, 128, 315], [220, 288, 254, 362], [257, 253, 273, 301], [218, 126, 234, 154], [207, 98, 223, 124], [198, 74, 212, 94]]
# Index: 207
# Image Shape: (3, 416, 416)
# Boxes: [(3.2968935070758505, 102.58351247594629, 108.96781039638198, 276.97657832261734), (159.89792131141286, 269.6714778365411, 212.27848247364162, 354.7768718356103), (212.45835852428291, 241.49214638672996, 240.10500469659794, 295.31865882851747), (205.1160997592778, 99.8343276885414, 228.21377310734945, 132.7494508876652), (200.4382949121779, 68.05644769547848, 223.08107097782516, 98.8804319703359), (197.85162898934436, 40.91574283337262, 217.0385742834523, 65.0114130530066)]
# Labels: [1, 1, 1, 1, 1, 1]
# the length is {'boxes': tensor([[  3.2969, 102.5835, 108.9678, 276.9766],
#         [159.8979, 269.6715, 212.2785, 354.7769],
#         [212.4584, 241.4921, 240.1050, 295.3187],
#         [205.1161,  99.8343, 228.2138, 132.7495],
#         [200.4383,  68.0564, 223.0811,  98.8804],
#         [197.8516,  40.9157, 217.0386,  65.0114]]), 'labels': tensor([1, 1, 1, 1, 1, 1]), 'image_id': tensor(207)}
# Index: 2003, Boxes: [[83, 22, 119, 102], [198, 47, 218, 89], [146, 9, 182, 115]]
# Index: 2003
# Image Shape: (3, 416, 416)
# Boxes: [(104.50530548824649, 26.86045235233146, 147.75672868152543, 111.5692125990465), (223.1568498799297, 61.67825516899392, 246.98877153587938, 106.23884535166168), (167.88699504850112, 18.63401427483286, 213.2300249524178, 129.9318985819433)]
# Labels: [7, 7, 7]
# the length is {'boxes': tensor([[104.5053,  26.8605, 147.7567, 111.5692],
#         [223.1568,  61.6783, 246.9888, 106.2388],
#         [167.8870,  18.6340, 213.2300, 129.9319]]), 'labels': tensor([7, 7, 7]), 'image_id': tensor(2003)}
# Index: 1491, Boxes: [[298, 255, 320, 307], [199, 292, 239, 416]]
# Index: 1491
# Image Shape: (3, 416, 416)
# Boxes: [(298.0, 255.00000000000003, 320.0, 307.0), (199.0, 292.0, 238.99999999999997, 416.0)]
# Labels: [4, 4]
# the length is {'boxes': tensor([[298., 255., 320., 307.],
#         [199., 292., 239., 416.]]), 'labels': tensor([4, 4]), 'image_id': tensor(1491)}
# Index: 6071, Boxes: [[204, 158, 230, 212], [170, 258, 190, 314], [293, 293, 315, 347], [139, 123, 165, 165], [114, 84, 142, 148], [40, 110, 54, 140], [188, 99, 198, 125], [119, 66, 133, 90]]
# Index: 6071
# Image Shape: (3, 416, 416)
# Boxes: [(166.8903548353003, 158.53318807933215, 192.7354063137306, 209.29849814502802), (207.22414412862616, 249.76558097866962, 227.59389962741537, 302.1756689468002), (92.9300769392965, 286.2579066520769, 115.07985090860464, 336.88797614968854), (225.75525938779816, 124.00185064314556, 251.1945891619759, 163.68132818147507), (245.68450952642957, 87.12764137867873, 273.71530117963135, 147.19876550122197), (327.85967841966345, 108.6449946784151, 341.80745396222227, 136.83291798512565), (194.45777652903553, 103.48688254744411, 204.5750339943881, 127.84428777694835), (253.3903013655755, 70.66794329773441, 267.13521605600806, 93.31295034076177)]
# Labels: [2, 2, 2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[166.8904, 158.5332, 192.7354, 209.2985],
#         [207.2242, 249.7656, 227.5939, 302.1757],
#         [ 92.9301, 286.2579, 115.0798, 336.8880],
#         [225.7553, 124.0019, 251.1946, 163.6813],
#         [245.6845,  87.1276, 273.7153, 147.1988],
#         [327.8597, 108.6450, 341.8075, 136.8329],
#         [194.4578, 103.4869, 204.5750, 127.8443],
#         [253.3903,  70.6679, 267.1352,  93.3130]]), 'labels': tensor([2, 2, 2, 2, 2, 2, 2, 2]), 'image_id': tensor(6071)}
# Index: 2900, Boxes: [[66, 175, 102, 247]]
# Index: 2900
# Image Shape: (3, 416, 416)
# Boxes: [(71.5, 189.58333333333334, 110.5, 267.5833333333333)]
# Labels: [2]
# the length is {'boxes': tensor([[ 71.5000, 189.5833, 110.5000, 267.5833]]), 'labels': tensor([2]), 'image_id': tensor(2900)}
# Index: 648, Boxes: [[205, 171, 311, 415]]
# Index: 648
# Image Shape: (3, 416, 416)
# Boxes: [(47.46900498964469, 161.70523701741942, 190.48558475224638, 416.0)]
# Labels: [5]
# the length is {'boxes': tensor([[ 47.4690, 161.7052, 190.4856, 416.0000]]), 'labels': tensor([5]), 'image_id': tensor(648)}
# Index: 1322, Boxes: [[113, 127, 135, 167], [120, 272, 148, 332], [227, 240, 249, 294], [227, 175, 243, 215], [163, 85, 179, 107], [112, 17, 140, 61]]
# Index: 1322
# Image Shape: (3, 416, 416)
# Boxes: [(112.99999999999999, 127.00000000000001, 135.0, 167.0), (119.99999999999999, 272.0, 148.0, 332.0), (226.99999999999997, 239.99999999999997, 249.0, 294.0), (226.99999999999997, 175.0, 243.0, 215.00000000000003), (163.0, 85.0, 179.0, 106.99999999999999), (112.0, 17.0, 140.0, 61.0)]
# Labels: [2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[113., 127., 135., 167.],
#         [120., 272., 148., 332.],
#         [227., 240., 249., 294.],
#         [227., 175., 243., 215.],
#         [163.,  85., 179., 107.],
#         [112.,  17., 140.,  61.]]), 'labels': tensor([2, 2, 2, 2, 2, 2]), 'image_id': tensor(1322)}
# Index: 2068, Boxes: [[146, 169, 168, 211], [8, 262, 60, 342], [137, 59, 165, 99], [24, 100, 36, 124]]
# Index: 2068
# Image Shape: (3, 416, 416)
# Boxes: [(273.26276255235075, 175.720249368617, 298.75887064439013, 222.52966856874534), (387.6173969878709, 281.2700310290658, 416.0, 370.75442382477604), (280.14598695936525, 55.067243767469236, 312.1643050009027, 99.87354847386003)]
# Labels: [2, 2, 2]
# the length is {'boxes': tensor([[273.2628, 175.7202, 298.7589, 222.5297],
#         [387.6174, 281.2700, 416.0000, 370.7544],
#         [280.1460,  55.0672, 312.1643,  99.8736]]), 'labels': tensor([2, 2, 2]), 'image_id': tensor(2068)}
# ...
# Labels: [5, 5, 5, 5, 5, 5]
# the length is {'boxes': tensor([[267.2944, 120.0838, 335.6839, 265.9342],
#         [250.6745,  58.6581, 290.2515, 130.9408],
#         [190.3328, 179.7549, 221.6278, 229.9848],
#         [170.5251, 183.1347, 188.3740, 216.4758],
#         [195.3730, 115.8536, 211.0641, 141.8729],
#         [227.1063,  40.9016, 242.4483,  59.6863]]), 'labels': tensor([5, 5, 5, 5, 5, 5]), 'image_id': tensor(6189)}
# Index: 5393, Boxes: [[57, 202, 131, 336]]
# Index: 5393
# Image Shape: (3, 416, 416)
# Boxes: [(285.0, 202.0, 359.0, 336.0)]
# Labels: [7]
# the length is {'boxes': tensor([[285., 202., 359., 336.]]), 'labels': tensor([7]), 'image_id': tensor(5393)}
# Index: 5784, Boxes: [[129, 48, 189, 238]]
# Index: 5784
# Image Shape: (3, 416, 416)
# Boxes: [(226.99999999999997, 48.0, 287.0, 238.0)]
# Labels: [5]
# the length is {'boxes': tensor([[227.,  48., 287., 238.]]), 'labels': tensor([5]), 'image_id': tensor(5784)}
# Index: 1454, Boxes: [[239, 231, 279, 309], [217, 237, 237, 299], [193, 50, 225, 114]]
# Index: 1454
# Image Shape: (3, 416, 416)
# Boxes: [(233.08266312766267, 242.07717307908163, 281.77652594770257, 329.2236655675808), (209.98494550402353, 247.03441576384947, 235.933575578123, 315.48332073466696), (196.91096478302674, 43.11315707662696, 235.97747755482067, 114.56083167449192)]
# Labels: [0, 0, 0]
# the length is {'boxes': tensor([[233.0827, 242.0772, 281.7765, 329.2237],
#         [209.9849, 247.0344, 235.9336, 315.4833],
#         [196.9110,  43.1132, 235.9775, 114.5608]]), 'labels': tensor([0, 0, 0]), 'image_id': tensor(1454)}
# Index: 480, Boxes: [[1, 167, 109, 335]]
# Index: 480
# Image Shape: (3, 416, 416)
# Boxes: [(300.9137055837563, 176.3248730964467, 414.94416243654825, 353.7055837563452)]
# Labels: [7]
# the length is {'boxes': tensor([[300.9137, 176.3249, 414.9442, 353.7056]]), 'labels': tensor([7]), 'image_id': tensor(480)}
# Index: 723, Boxes: [[106, 1, 134, 69], [78, 124, 196, 410]]
# Index: 723
# Image Shape: (3, 416, 416)
# Boxes: [(279.9883287523044, 0.0, 319.14945500578733, 66.47875171443707), (231.21992626114942, 117.10802967472037, 396.17684161489177, 416.0)]
# Labels: [7, 7]
# the length is {'boxes': tensor([[279.9883,   0.0000, 319.1494,  66.4788],
#         [231.2199, 117.1080, 396.1768, 416.0000]]), 'labels': tensor([7, 7]), 'image_id': tensor(723)}
# Index: 1846, Boxes: [[83, 115, 153, 243], [76, 72, 128, 160]]
# Index: 1846
# Image Shape: (3, 416, 416)
# Boxes: [(230.40142977149728, 107.96282278626751, 302.00531246157175, 234.57401019598402), (253.63731524524684, 65.86443497143807, 306.64211762981205, 153.01170235440182)]
# Labels: [7, 7]
# the length is {'boxes': tensor([[230.4014, 107.9628, 302.0053, 234.5740],
#         [253.6373,  65.8644, 306.6421, 153.0117]]), 'labels': tensor([7, 7]), 'image_id': tensor(1846)}
# Index: 1555, Boxes: [[0, 132, 78, 320], [301, 239, 331, 307]]
# Index: 1555
# Image Shape: (3, 416, 416)
# Boxes: [(365.3, 85.8, 416.0, 208.0), (200.85, 155.35, 220.35, 199.54999999999998)]
# Labels: [7, 7]
# the length is {'boxes': tensor([[365.3000,  85.8000, 416.0000, 208.0000],
#         [200.8500, 155.3500, 220.3500, 199.5500]]), 'labels': tensor([7, 7]), 'image_id': tensor(1555)}
# Index: 5409, Boxes: [[29, 160, 109, 298]]
# Index: 5409
# Image Shape: (3, 416, 416)
# Boxes: [(25.43306764466623, 106.58279107308381, 132.45367783744507, 253.96441102488654)]
# Labels: [7]
# the length is {'boxes': tensor([[ 25.4331, 106.5828, 132.4537, 253.9644]]), 'labels': tensor([7]), 'image_id': tensor(5409)}
# Index: 1698, Boxes: [[128, 180, 174, 286]]
# Index: 1698
# Image Shape: (3, 416, 416)
# Boxes: [(241.99999999999997, 180.0, 288.0, 286.0)]
# Labels: [2]
# the length is {'boxes': tensor([[242., 180., 288., 286.]]), 'labels': tensor([2]), 'image_id': tensor(1698)}
# Index: 2706, Boxes: [[139, 129, 199, 287], [300, 151, 316, 183], [334, 231, 356, 285], [213, 71, 221, 91]]
# Index: 2706
# Image Shape: (3, 416, 416)
# Boxes: [(139.0, 129.0, 199.0, 287.0), (300.0, 151.0, 316.0, 183.0), (334.0, 231.0, 356.0, 285.0), (212.99999999999997, 71.0, 221.0, 91.0)]
# Labels: [1, 1, 1, 1]
# the length is {'boxes': tensor([[139., 129., 199., 287.],
#         [300., 151., 316., 183.],
#         [334., 231., 356., 285.],
#         [213.,  71., 221.,  91.]]), 'labels': tensor([1, 1, 1, 1]), 'image_id': tensor(2706)}
# Index: 6123, Boxes: [[220, 169, 272, 283], [201, 98, 217, 144], [220, 118, 230, 134], [78, 116, 126, 168], [1, 175, 69, 343]]
# Index: 6123
# Image Shape: (3, 416, 416)
# Boxes: [(144.0, 169.0, 196.0, 283.0), (199.0, 98.0, 215.00000000000003, 144.0), (186.0, 118.0, 196.0, 134.0), (290.0, 116.0, 338.0, 168.0), (347.0, 175.0, 415.0, 343.0)]
# Labels: [1, 1, 1, 1, 1]
# the length is {'boxes': tensor([[144., 169., 196., 283.],
#         [199.,  98., 215., 144.],
#         [186., 118., 196., 134.],
#         [290., 116., 338., 168.],
#         [347., 175., 415., 343.]]), 'labels': tensor([1, 1, 1, 1, 1]), 'image_id': tensor(6123)}
# Index: 1993, Boxes: [[191, 187, 239, 295], [319, 100, 331, 140], [215, 52, 225, 86], [245, 28, 255, 50], [267, 39, 277, 65], [87, 31, 95, 53], [13, 66, 31, 100]]
# Index: 1993
# Image Shape: (3, 416, 416)
# Boxes: [(177.00000000000003, 187.0, 225.0, 295.0), (85.00000000000003, 100.0, 96.99999999999997, 140.0), (191.0, 52.0, 200.99999999999997, 86.0), (160.99999999999997, 28.0, 171.0, 50.0), (139.0, 39.0, 148.99999999999997, 65.0), (321.0, 31.0, 329.0, 53.0), (385.0, 66.0, 403.0, 100.0)]
# Labels: [2, 2, 2, 2, 2, 2, 2]
# the length is {'boxes': tensor([[177., 187., 225., 295.],
#         [ 85., 100.,  97., 140.],
#         [191.,  52., 201.,  86.],
#         [161.,  28., 171.,  50.],
#         [139.,  39., 149.,  65.],
#         [321.,  31., 329.,  53.],
#         [385.,  66., 403., 100.]]), 'labels': tensor([2, 2, 2, 2, 2, 2, 2]), 'image_id': tensor(1993)}
# Index: 4353, Boxes: [[210, 163, 290, 413]]
# Index: 4353
# Image Shape: (3, 416, 416)
# Boxes: [(210.0, 163.0, 290.0, 413.0)]
# Labels: [7]
# the length is {'boxes': tensor([[210., 163., 290., 413.]]), 'labels': tensor([7]), 'image_id': tensor(4353)}
# Index: 1186, Boxes: [[204, 191, 252, 291], [253, 297, 279, 357]]
# Index: 1186
# Image Shape: (3, 416, 416)
# Boxes: [(167.47007756912586, 182.83169585560438, 233.7270070845807, 288.71729185902575), (201.4036736623238, 294.6934543128957, 238.4625304939875, 357.6633623097683)]
# Labels: [3, 3]
# the length is {'boxes': tensor([[167.4701, 182.8317, 233.7270, 288.7173],
#         [201.4037, 294.6935, 238.4625, 357.6634]]), 'labels': tensor([3, 3]), 'image_id': tensor(1186)}
# Index: 6091, Boxes: [[91, 237, 129, 319]]
# Index: 6091
# Image Shape: (3, 416, 416)
# Boxes: [(91.0, 237.0, 129.0, 319.0)]
# Labels: [2]
# the length is {'boxes': tensor([[ 91., 237., 129., 319.]]), 'labels': tensor([2]), 'image_id': tensor(6091)}
# Index: 182, Boxes: [[231, 150, 325, 388], [159, 88, 179, 112]]
# Index: 182
# Image Shape: (3, 416, 416)
# Boxes: [(42.76937077610131, 148.6079146322989, 190.07437182492754, 409.61784040469576), (250.94558523814504, 118.14198919219072, 276.423363395633, 146.77823748088898)]
# Labels: [5, 5]
# the length is {'boxes': tensor([[ 42.7694, 148.6079, 190.0744, 409.6178],
#         [250.9456, 118.1420, 276.4234, 146.7782]]), 'labels': tensor([5, 5]), 'image_id': tensor(182)}
# Index: 6437, Boxes: [[92, 116, 118, 162], [192, 87, 206, 109], [223, 171, 237, 213], [130, 52, 146, 74]]
# Index: 6437
# Image Shape: (3, 416, 416)
# Boxes: [(298.0, 116.0, 324.0, 162.0), (210.0, 87.0, 224.0, 109.0), (179.0, 171.0, 193.0, 212.99999999999997), (270.0, 52.0, 286.0, 74.0)]
# Labels: [2, 2, 2, 2]
# the length is {'boxes': tensor([[298., 116., 324., 162.],
#         [210.,  87., 224., 109.],
#         [179., 171., 193., 213.],
#         [270.,  52., 286.,  74.]]), 'labels': tensor([2, 2, 2, 2]), 'image_id': tensor(6437)}
# Index: 2397, Boxes: [[167, 74, 201, 156], [111, 154, 209, 402], [253, 164, 265, 216], [236, 111, 246, 141]]
# Index: 2397
# Image Shape: (3, 416, 416)
# Boxes: [(191.20824771709343, 101.3010401189293, 225.21711039476696, 176.74757887079272), (174.10436003994897, 173.25449420529876, 272.5975122715264, 401.24038416871963), (130.97965297867495, 180.04053242975817, 143.90854811223247, 227.5008242918073), (151.1559844686294, 132.92139757840775, 161.3947562226336, 160.42586769665772)]
# Labels: [7, 7, 7, 7]
# the length is {'boxes': tensor([[191.2083, 101.3010, 225.2171, 176.7476],
#         [174.1044, 173.2545, 272.5975, 401.2404],
#         [130.9797, 180.0405, 143.9086, 227.5008],
#         [151.1560, 132.9214, 161.3948, 160.4259]]), 'labels': tensor([7, 7, 7, 7]), 'image_id': tensor(2397)}
# Index: 907, Boxes: [[197, 184, 237, 240], [199, 112, 219, 160], [221, 267, 245, 309], [142, 71, 178, 141]]
# Index: 907
# Image Shape: (3, 416, 416)
# Boxes: [(202.85148514851485, 189.46534653465346, 244.03960396039602, 247.12871287128712), (204.9108910891089, 115.32673267326734, 225.5049504950495, 164.75247524752476), (227.5643564356436, 274.9306930693069, 252.27722772277227, 318.1782178217822), (146.21782178217822, 73.10891089108911, 183.2871287128713, 145.18811881188117)]
# Labels: [2, 2, 2, 2]
# the length is {'boxes': tensor([[202.8515, 189.4653, 244.0396, 247.1287],
#         [204.9109, 115.3267, 225.5049, 164.7525],
#         [227.5644, 274.9307, 252.2772, 318.1782],
#         [146.2178,  73.1089, 183.2871, 145.1881]]), 'labels': tensor([2, 2, 2, 2]), 'image_id': tensor(907)}
# Index: 5033, Boxes: [[79, 82, 143, 190]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[253], line 2
#       1 ## Inspecting code
# ----> 2 for batch_idx, (imgs, targets) in enumerate(training_loader):
#       3     print((f"the length is {(targets[0])}"))
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[197], line 68, in CustomDataset.__getitem__(self, idx)
#      66 try:
#      67     print(f"Index: {idx}, Boxes: {boxes}")
# ---> 68     augmented = self.transform(image=np.array(img), bboxes=boxes, labels=labels)
#      69     img = augmented['image']
#      70     boxes = augmented['bboxes']
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/core/composition.py:210, in Compose.__call__(self, force_apply, *args, **data)
#     207     p.preprocess(data)
#     209 for idx, t in enumerate(transforms):
# --> 210     data = t(**data)
#     212     if check_each_transform:
#     213         data = self._check_data_post_transform(data)
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/core/transforms_interface.py:118, in BasicTransform.__call__(self, force_apply, *args, **kwargs)
#     113             warn(
#     114                 self.get_class_fullname() + " could work incorrectly in ReplayMode for other input data"
#     115                 " because its' params depend on targets."
#     116             )
#     117         kwargs[self.save_key][id(self)] = deepcopy(params)
# --> 118     return self.apply_with_params(params, **kwargs)
#     120 return kwargs
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/core/transforms_interface.py:131, in BasicTransform.apply_with_params(self, params, **kwargs)
#     129     target_function = self._get_target_function(key)
#     130     target_dependencies = {k: kwargs[k] for k in self.target_dependence.get(key, [])}
# --> 131     res[key] = target_function(arg, **dict(params, **target_dependencies))
#     132 else:
#     133     res[key] = None
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/geometric/resize.py:90, in LongestMaxSize.apply(self, img, max_size, interpolation, **params)
#      87 def apply(
#      88     self, img: np.ndarray, max_size: int = 1024, interpolation: int = cv2.INTER_LINEAR, **params
#      89 ) -> np.ndarray:
# ---> 90     return F.longest_max_size(img, max_size=max_size, interpolation=interpolation)
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/utils.py:122, in preserve_channel_dim.<locals>.wrapped_function(img, *args, **kwargs)
#     119 @wraps(func)
#     120 def wrapped_function(img: np.ndarray, *args: P.args, **kwargs: P.kwargs) -> np.ndarray:
#     121     shape = img.shape
# --> 122     result = func(img, *args, **kwargs)
#     123     if len(shape) == 3 and shape[-1] == 1 and len(result.shape) == 2:
#     124         result = np.expand_dims(result, axis=-1)
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/geometric/functional.py:439, in longest_max_size(img, max_size, interpolation)
#     437 @preserve_channel_dim
#     438 def longest_max_size(img: np.ndarray, max_size: int, interpolation: int) -> np.ndarray:
# --> 439     return _func_max_size(img, max_size, interpolation, max)
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/geometric/functional.py:433, in _func_max_size(img, max_size, interpolation, func)
#     431 if scale != 1.0:
#     432     new_height, new_width = tuple(py3round(dim * scale) for dim in (height, width))
# --> 433     img = resize(img, height=new_height, width=new_width, interpolation=interpolation)
#     434 return img
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/utils.py:122, in preserve_channel_dim.<locals>.wrapped_function(img, *args, **kwargs)
#     119 @wraps(func)
#     120 def wrapped_function(img: np.ndarray, *args: P.args, **kwargs: P.kwargs) -> np.ndarray:
#     121     shape = img.shape
# --> 122     result = func(img, *args, **kwargs)
#     123     if len(shape) == 3 and shape[-1] == 1 and len(result.shape) == 2:
#     124         result = np.expand_dims(result, axis=-1)
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/geometric/functional.py:392, in resize(img, height, width, interpolation)
#     390     return img
#     391 resize_fn = _maybe_process_in_chunks(cv2.resize, dsize=(width, height), interpolation=interpolation)
# --> 392 return resize_fn(img)
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/utils.py:208, in _maybe_process_in_chunks.<locals>.__process_fn(img)
#     206     img = np.dstack(chunks)
#     207 else:
# --> 208     img = process_fn(img, **kwargs)
#     209 return img
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.transforms import ToTensor
from PIL import Image

# Assuming your model is defined as "model"
model = SimpleCNN(num_classes=7)  # Replace with your model definition
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define loss and optimizer
criterion = nn.CrossEntropyLoss() 
optimizer = optim.Adam(model.parameters(), lr=0.001)

transform = ToTensor()
num_epochs = 10

for epoch in range(num_epochs):
    
    # Training Loop
    model.train()  # Set model to training mode
    for batch_idx, (imgs, targets) in enumerate(training_loader):
        
        # Convert images in list to tensor and move to device
#         for i in range(len(imgs)):
#             if isinstance(imgs[i], Image.Image):
#                 imgs[i] = transform(imgs[i])
#         imgs = [img.to(device) for img in imgs]
        imgs = [transform(img) if isinstance(img, Image.Image) else img for img in imgs]
        imgs = torch.stack(imgs).to(device)
        
        # Move targets to device
#         for i in range(len(targets)):
        targets[0]['boxes'] = targets[0]['boxes'].to(device) ## Added 0 to get rid of the tuple
        targets[0]['labels'] = targets[0]['labels'].to(device)
        targets[0]['image_id'] = targets[0]['image_id'].to(device)
        
      
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(imgs)
        
        loss = criterion(outputs, targets[0])
        
        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        # Print some statistics (optional)
        if batch_idx % 10 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(training_loader)}], Loss: {loss.item():.4f}")

    # Testing Loop
    model.eval()  # Set model to evaluation mode
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (imgs, targets) in enumerate(testing_loader):
            
            # Convert images in list to tensor and move to device
            for i in range(len(imgs)):
                if isinstance(imgs[i], Image.Image):
                    imgs[i] = transform(imgs[i])
            imgs = [img.to(device) for img in imgs]
            
            # Move targets to device
#             for i in range(len(targets)):
            targets[0]['boxes'] = targets[0]['boxes'].to(device)
            targets[0]['labels'] = targets[0]['labels'].to(device)
            targets[0]['image_id'] = targets[0]['image_id'].to(device)
 
            
            outputs = model(imgs)
            loss = criterion(outputs, targets[0])

            test_loss += loss.item()
            # Your accuracy computation may vary based on your model and problem
            _, predicted = outputs.max(1)
            total += len(targets)  # Assuming each target corresponds to an image
            correct += sum([int(predicted[i] == targets[i]['labels']) for i in range(len(predicted))])

        print(f"Epoch [{epoch+1}/{num_epochs}], Test Loss: {test_loss/len(testing_loader):.4f}, Accuracy: {100 * correct/total:.2f}%")
# Out:
# Index: 5304, Boxes: [[103, 142, 125, 178], [201, 110, 215, 136], [222, 125, 232, 155], [229, 127, 241, 159], [103, 48, 119, 64], [11, 51, 47, 93]]
# Index: 5304
# Image Shape: (3, 416, 416)
# Boxes: [(249.9158365176579, 103.79805631721068, 277.81005331197525, 142.03271241897087), (158.94702325611954, 93.41392219027458, 177.31846602940968, 120.64859865565862), (145.98922535236076, 111.72086742465444, 161.40625689495286, 141.90995512073647), (137.93637447676704, 115.00504881981907, 155.63371198129283, 147.47444247783477), (236.67924573884125, 15.496534251067304, 254.92169343431087, 33.738981946536946), (304.9167793898683, 0.0, 347.16693722455204, 46.52513464331165)]
# Labels: [2, 2, 2, 2, 2, 2]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[250], line 45
#      42 # Forward pass
#      43 outputs = model(imgs)
# ---> 45 loss = criterion(outputs, targets[0])
#      47 # Backward pass and optimize
#      48 loss.backward()
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/loss.py:1174, in CrossEntropyLoss.forward(self, input, target)
#    1173 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1174     return F.cross_entropy(input, target, weight=self.weight,
#    1175                            ignore_index=self.ignore_index, reduction=self.reduction,
#    1176                            label_smoothing=self.label_smoothing)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:3029, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3027 if size_average is not None or reduce is not None:
#    3028     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3029 return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#
# TypeError: cross_entropy_loss(): argument 'target' (position 2) must be Tensor, not dict

# %%
for i in range(1):
    print(i)

# %%
 # This assumes 'labels' is a key in your dictionary

    # rest of your training loop...

# %%
/kaggle/input/dataset-vehicle1/images/Highway_0_2020-07-30_jpg.rf.7d947cc31b302b22a527ecd17d3af963.jpg
